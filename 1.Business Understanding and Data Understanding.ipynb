# %%
import pandas as pd
pd.set_option('display.max_rows', 500)

# %%
pd_raw= pd.read_csv('../data/raw/COVID-19/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv')

# %%
pd_raw
# Out:
#                                    Province/State  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# 5                                             NaN
# 6                                             NaN
# 7                                             NaN
# 8                    Australian Capital Territory
# 9                                 New South Wales
# 10                             Northern Territory
# 11                                     Queensland
# 12                                South Australia
# 13                                       Tasmania
# 14                                       Victoria
# 15                              Western Australia
# 16                                            NaN
# 17                                            NaN
# 18                                            NaN
# 19                                            NaN
# 20                                            NaN
# 21                                            NaN
# 22                                            NaN
# 23                                            NaN
# 24                                            NaN
# 25                                            NaN
# 26                                            NaN
# 27                                            NaN
# 28                                            NaN
# 29                                            NaN
# 30                                            NaN
# 31                                            NaN
# 32                                            NaN
# 33                                            NaN
# 34                                            NaN
# 35                                            NaN
# 36                                            NaN
# 37                                            NaN
# 38                                            NaN
# 39                                        Alberta
# 40                               British Columbia
# 41                               Diamond Princess
# 42                                 Grand Princess
# 43                                       Manitoba
# 44                                  New Brunswick
# 45                      Newfoundland and Labrador
# 46                          Northwest Territories
# 47                                    Nova Scotia
# 48                                        Nunavut
# 49                                        Ontario
# 50                           Prince Edward Island
# 51                                         Quebec
# 52                         Repatriated Travellers
# 53                                   Saskatchewan
# 54                                          Yukon
# 55                                            NaN
# 56                                            NaN
# 57                                            NaN
# 58                                          Anhui
# 59                                        Beijing
# 60                                      Chongqing
# 61                                         Fujian
# 62                                          Gansu
# 63                                      Guangdong
# 64                                        Guangxi
# 65                                        Guizhou
# 66                                         Hainan
# 67                                          Hebei
# 68                                   Heilongjiang
# 69                                          Henan
# 70                                      Hong Kong
# 71                                          Hubei
# 72                                          Hunan
# 73                                 Inner Mongolia
# 74                                        Jiangsu
# 75                                        Jiangxi
# 76                                          Jilin
# 77                                       Liaoning
# 78                                          Macau
# 79                                        Ningxia
# 80                                        Qinghai
# 81                                        Shaanxi
# 82                                       Shandong
# 83                                       Shanghai
# 84                                         Shanxi
# 85                                        Sichuan
# 86                                        Tianjin
# 87                                          Tibet
# 88                                        Unknown
# 89                                       Xinjiang
# 90                                         Yunnan
# 91                                       Zhejiang
# 92                                            NaN
# 93                                            NaN
# 94                                            NaN
# 95                                            NaN
# 96                                            NaN
# 97                                            NaN
# 98                                            NaN
# 99                                            NaN
# 100                                           NaN
# 101                                           NaN
# 102                                 Faroe Islands
# 103                                     Greenland
# 104                                           NaN
# 105                                           NaN
# 106                                           NaN
# 107                                           NaN
# 108                                           NaN
# 109                                           NaN
# 110                                           NaN
# 111                                           NaN
# 112                                           NaN
# 113                                           NaN
# 114                                           NaN
# 115                                           NaN
# 116                                           NaN
# 117                                           NaN
# 118                                           NaN
# 119                                 French Guiana
# 120                              French Polynesia
# 121                                    Guadeloupe
# 122                                    Martinique
# 123                                       Mayotte
# 124                                 New Caledonia
# 125                                       Reunion
# 126                              Saint Barthelemy
# 127                     Saint Pierre and Miquelon
# 128                                     St Martin
# 129                             Wallis and Futuna
# 130                                           NaN
# 131                                           NaN
# 132                                           NaN
# 133                                           NaN
# 134                                           NaN
# 135                                           NaN
# 136                                           NaN
# 137                                           NaN
# 138                                           NaN
# 139                                           NaN
# 140                                           NaN
# 141                                           NaN
# 142                                           NaN
# 143                                           NaN
# 144                                           NaN
# 145                                           NaN
# 146                                           NaN
# 147                                           NaN
# 148                                           NaN
# 149                                           NaN
# 150                                           NaN
# 151                                           NaN
# 152                                           NaN
# 153                                           NaN
# 154                                           NaN
# 155                                           NaN
# 156                                           NaN
# 157                                           NaN
# 158                                           NaN
# 159                                           NaN
# 160                                           NaN
# 161                                           NaN
# 162                                           NaN
# 163                                           NaN
# 164                                           NaN
# 165                                           NaN
# 166                                           NaN
# 167                                           NaN
# 168                                           NaN
# 169                                           NaN
# 170                                           NaN
# 171                                           NaN
# 172                                           NaN
# 173                                           NaN
# 174                                           NaN
# 175                                           NaN
# 176                                           NaN
# 177                                           NaN
# 178                                           NaN
# 179                                           NaN
# 180                                           NaN
# 181                                           NaN
# 182                                           NaN
# 183                                           NaN
# 184                                           NaN
# 185                                           NaN
# 186                                           NaN
# 187                                           NaN
# 188                                           NaN
# 189                                           NaN
# 190                                           NaN
# 191                                           NaN
# 192                                           NaN
# 193                                         Aruba
# 194              Bonaire, Sint Eustatius and Saba
# 195                                       Curacao
# 196                                  Sint Maarten
# 197                                           NaN
# 198                                  Cook Islands
# 199                                           NaN
# 200                                           NaN
# 201                                           NaN
# 202                                           NaN
# 203                                           NaN
# 204                                           NaN
# 205                                           NaN
# 206                                           NaN
# 207                                           NaN
# 208                                           NaN
# 209                                           NaN
# 210                                           NaN
# 211                                           NaN
# 212                                           NaN
# 213                                           NaN
# 214                                           NaN
# 215                                           NaN
# 216                                           NaN
# 217                                           NaN
# 218                                           NaN
# 219                                           NaN
# 220                                           NaN
# 221                                           NaN
# 222                                           NaN
# 223                                           NaN
# 224                                           NaN
# 225                                           NaN
# 226                                           NaN
# 227                                           NaN
# 228                                           NaN
# 229                                           NaN
# 230                                           NaN
# 231                                           NaN
# 232                                           NaN
# 233                                           NaN
# 234                                           NaN
# 235                                           NaN
# 236                                           NaN
# 237                                           NaN
# 238                                           NaN
# 239                                           NaN
# 240                                           NaN
# 241                                           NaN
# 242                                           NaN
# 243                                           NaN
# 244                                           NaN
# 245                                           NaN
# 246                                           NaN
# 247                                           NaN
# 248                                           NaN
# 249                                           NaN
# 250                                           NaN
# 251                                           NaN
# 252                                           NaN
# 253                                           NaN
# 254                                           NaN
# 255                                           NaN
# 256                                           NaN
# 257                                           NaN
# 258                                           NaN
# 259                                      Anguilla
# 260                                       Bermuda
# 261                        British Virgin Islands
# 262                                Cayman Islands
# 263                               Channel Islands
# 264                   Falkland Islands (Malvinas)
# 265                                     Gibraltar
# 266                                   Isle of Man
# 267                                    Montserrat
# 268  Saint Helena, Ascension and Tristan da Cunha
# 269                      Turks and Caicos Islands
# 270                                           NaN
# 271                                           NaN
# 272                                           NaN
# 273                                           NaN
# 274                                           NaN
# 275                                           NaN
# 276                                           NaN
# 277                                           NaN
# 278                                           NaN
# 279                                           NaN
#
#                        Country/Region        Lat        Long  1/22/20  \
# 0                         Afghanistan  33.939110   67.709953        0
# 1                             Albania  41.153300   20.168300        0
# 2                             Algeria  28.033900    1.659600        0
# 3                             Andorra  42.506300    1.521800        0
# 4                              Angola -11.202700   17.873900        0
# 5                 Antigua and Barbuda  17.060800  -61.796400        0
# 6                           Argentina -38.416100  -63.616700        0
# 7                             Armenia  40.069100   45.038200        0
# 8                           Australia -35.473500  149.012400        0
://www.rki.de/DE/Content/InfAZ/N/Neuartiges_Coronavirus/Fallzahlen.html")

# %%
soup = BeautifulSoup(page.content, 'html.parser')

# %%
html_table=soup.find('table')

# %%
all_rows =html_table.find_all('tr')

# %%
final_data_list=[]

# %%
for pos, rows in enumerate(all_rows):
    #print(pos)
    #print(rows)
    col_list=[each_col.get_text(strip=True)for each_col in rows.find_all('td')]
    final_data_list.append(col_list)

# %%
pd.DataFrame(final_data_list).dropna().rename(columns={0:'state'})
# Out:
#                        state          1       2        3      4        5
# 2         Baden-Württem­berg    972.422   2.322   38.371  345,6   12.571
# 3                     Bayern  1.284.477   2.843   37.470  285,2   19.033
# 4                     Berlin    309.718     243   11.604  316,7    3.964
# 5               Branden­burg    225.087     791   14.818  585,4    4.462
# 6                     Bremen     44.297     239    1.885  277,2      575
# 7                    Hamburg    128.858     593    5.339  288,2    1.953
# 8                     Hessen    458.825     880   12.731  202,3    8.411
# 9   Meck­lenburg-Vor­pommern     92.583     280    6.775  420,6    1.423
# 10            Nieder­sachsen    422.005     677   14.174  177,1    6.685
# 11     Nord­rhein-West­falen  1.320.344   2.639   42.711  238,3   19.829
# 12          Rhein­land-Pfalz    266.827     410    8.475  206,8    4.488
# 13                  Saarland     70.943      93    2.717  276,1    1.198
# 14                   Sachsen    622.292   2.554   29.179  719,2   12.253
# 15            Sachsen-Anhalt    210.417     449   14.387  659,7    4.087
# 16       Schles­wig-Holstein    109.840     229    4.901  168,4    1.856
# 17                 Thüringen    270.687     844   17.273  814,7    5.564
# 18                    Gesamt  6.809.622  16.086  262.810  316,0  108.352
# 21        Baden-Württem­berg    972.422   2.322   38.371  345,6   12.571
# 22                    Bayern  1.284.477   2.843   37.470  285,2   19.033
# 23                    Berlin    309.718     243   11.604  316,7    3.964
# 24              Branden­burg    225.087     791   14.818  585,4    4.462
# 25                    Bremen     44.297     239    1.885  277,2      575
# 26                   Hamburg    128.858     593    5.339  288,2    1.953
# 27                    Hessen    458.825     880   12.731  202,3    8.411
# 28  Meck­lenburg-Vor­pommern     92.583     280    6.775  420,6    1.423
# 29            Nieder­sachsen    422.005     677   14.174  177,1    6.685
# 30     Nord­rhein-West­falen  1.320.344   2.639   42.711  238,3   19.829
# 31          Rhein­land-Pfalz    266.827     410    8.475  206,8    4.488
# 32                  Saarland     70.943      93    2.717  276,1    1.198
# 33                   Sachsen    622.292   2.554   29.179  719,2   12.253
# 34            Sachsen-Anhalt    210.417     449   14.387  659,7    4.087
# 35       Schles­wig-Holstein    109.840     229    4.901  168,4    1.856
# 36                 Thüringen    270.687     844   17.273  814,7    5.564
# 37                    Gesamt  6.809.622  16.086  262.810  316,0  108.352

# %%
data=requests.get('https://api.coronavirus.data.gov.uk/v1/data?filters=areaName=England;areaType=nation&structure={%22date%22:%22date%22,%22name%22:%22areaName%22,%22code%22:%22areaCode%22,%22newCasesByPublishDate%22:%22newCasesByPublishDate%22,%22cumCasesByPublishDate%22:%22cumCasesByPublishDate%22,%22newDeaths28DaysByPublishDate%22:%22newDeaths28DaysByPublishDate%22,%22cumDeaths28DaysByPublishDate%22:%22cumDeaths28DaysByPublishDate%22}')

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-84-e0f371d3169f> in <module>
# ----> 1 full_list=data['data']
#
# TypeError: 'Response' object is not subscriptable

# %%
print(data.json())
# Out:
# {'length': 690, 'maxPageLimit': 2500, 'totalRecords': 2690, 'data': [{'date': '2021-12-20', 'name': 'England', 'code': 'E92000001', 'newCasesByPublishDate': 76065, 'cumCasesByPublishDate': 9731126, 'newDeaths28DaysByPublishDate': 35, 'cumDeaths28DaysByPublishDate': 128012}, {'date': '2021-12-19', 'name': 'England', 'code': 'E92000001', 'newCasesByPublishDate': 71702, 'cumCasesByPublishDate': 9655061, 'newDeaths28DaysByPublishDate': 38, 'cumDeaths28DaysByPublishDate': 127977}, {'date': '2021-12-18', 'name': 'England', 'code': 'E92000001', 'newCasesByPublishDate': 82426, 'cumCasesByPublishDate': 9584269, 'newDeaths28DaysByPublishDate': 111, 'cumDeaths28DaysByPublishDate': 127939}, {'date': '2021-12-17', 'name': 'England', 'code': 'E92000001', 'newCasesByPublishDate': 83693, 'cumCasesByPublishDate': 9503176, 'newDeaths28DaysByPublishDate': 98, 'cumDeaths28DaysByPublishDate': 127828}, {'date': '2021-12-16', 'name': 'England', 'code': 'E92000001', 'newCasesByPublishDate': 77299, 'cumCasesByPublishDate': 9420017, 'newDeaths28DaysByPublishDate': 122, 'cumDeaths28DaysByPublishDate': 127730}, {'date': '2021-12-15', 'name': 'England', 'code': 'E92000001', 'newCasesByPublishDate': 68868, 'cumCasesByPublishDate': 9343520, 'newDeaths28DaysByPublishDate': 129, 'cumDeaths28DaysByPublishDate': 127608}, {'date': '2021-12-14', 'name': 'England', 'code': 'E92000001', 'newCasesByPublishDate': 53093, 'cumCasesByPublishDate': 9275513, 'newDeaths28DaysByPublishDate': 138, 'cumDeaths28DaysByPublishDate': 127479}, {'date': '2021-12-13', 'name': 'England', 'code': 'E92000001', 'newCasesByPublishDate': 44931, 'cumCasesByPublishDate': 9222932, 'newDeaths28DaysByPublishDate': 26, 'cumDeaths28DaysByPublishDate': 127341}, {'date': '2021-12-12', 'name': 'England', 'code': 'E92000001', 'newCasesByPublishDate': 40713, 'cumCasesByPublishDate': 9178705, 'newDeaths28DaysByPublishDate': 44, 'cumDeaths28DaysByPublishDate': 127315}, {'date': '2021-12-11', 'name': 'England', 'code': 'E92000001', 'newCasesByPublishDate': 48540, 'cumCasesByPublishDate': 9138773, 'newDeaths28DaysByPublishDate': 117, 'cumDeaths28DaysByPublishDate': 127271}, {'date': '2021-12-10', 'name': 'England', 'code': 'E92000001', 'newCasesByPublishDate': 48908, 'cumCasesByPublishDate': 9092016, 'newDeaths28DaysByPublishDate': 90, 'cumDeaths28DaysByPublishDate': 127154}, {'date': '2021-12-09', 'name': 'England', 'code': 'E92000001', 'newCasesByPublishDate': 43550, 'cumCasesByPublishDate': 9043108, 'newDeaths28DaysByPublishDate': 113, 'cumDeaths28DaysByPublishDate': 127064}, {'date': '2021-12-08', 'name': 'England', 'code': 'E92000001', 'newCasesByPublishDate': 44019, 'cumCasesByPublishDate': 9000391, 'newDeaths28DaysByPublishDate': 134, 'cumDeaths28DaysByPublishDate': 126951}, {'date': '2021-12-07', 'name': 'England', 'code': 'E92000001', 'newCasesByPublishDate': 38866, 'cumCasesByPublishDate': 8957091, 'newDeaths28DaysByPublishDate': 161, 'cumDeaths28DaysByPublishDate': 126817}, {'date': '2021-12-06', 'name': 'England', 'code': 'E92000001', 'newCasesByPublishDate': 41525, 'cumCasesByPublishDate': 8918807, 'newDeaths28DaysByPublishDate': 34, 'cumDeaths28DaysByPublishDate': 126656}, {'date': '2021-12-05', 'name': 'England', 'code': 'E92000001', 'newCasesByPublishDate': 37396, 'cumCasesByPublishDate': 8877883, 'newDeaths28DaysByPublishDate': 41, 'cumDeaths28DaysByPublishDate': 126622}, {'date': '2021-12-04', 'name': 'England', 'code': 'E92000001', 'newCasesByPublishDate': 39949, 'cumCasesByPublishDate': 8841194, 'newDeaths28DaysByPublishDate': 104, 'cumDeaths28DaysByPublishDate': 126581}, {'date': '2021-12-03', 'name': 'England', 'code': 'E92000001', 'newCasesByPublishDate': 43888, 'cumCasesByPublishDate': 8802632, 'newDeaths28DaysByPublishDate': 115, 'cumDeaths28DaysByPublishDate': 126477}, {'date': '2021-12-02', 'name': 'England', 'code': 'E92000001', 'newCasesByPublishDate': 45880, 'cumCasesByPublishDate': 8758744, 'newDeaths28DaysByPublishDate': 104, 'cumDeaths28DaysByPublishDate': 126362}, {'date ...

# %%
import json

# %%
json_object = json.loads(data.content)

# %%
type(json_object)
# Out:
# dict

# %%
json_object.keys()
# Out:
# dict_keys(['length', 'maxPageLimit', 'totalRecords', 'data', 'requestPayload', 'pagination'])

# %%
len(json_object['data'])
# Out:
# 690

# %%
json_object
# Out:
# {'length': 690,
#  'maxPageLimit': 2500,
#  'totalRecords': 2690,
#  'data': [{'date': '2021-12-20',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 76065,
#    'cumCasesByPublishDate': 9731126,
#    'newDeaths28DaysByPublishDate': 35,
#    'cumDeaths28DaysByPublishDate': 128012},
#   {'date': '2021-12-19',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 71702,
#    'cumCasesByPublishDate': 9655061,
#    'newDeaths28DaysByPublishDate': 38,
#    'cumDeaths28DaysByPublishDate': 127977},
#   {'date': '2021-12-18',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 82426,
#    'cumCasesByPublishDate': 9584269,
#    'newDeaths28DaysByPublishDate': 111,
#    'cumDeaths28DaysByPublishDate': 127939},
#   {'date': '2021-12-17',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 83693,
#    'cumCasesByPublishDate': 9503176,
#    'newDeaths28DaysByPublishDate': 98,
#    'cumDeaths28DaysByPublishDate': 127828},
#   {'date': '2021-12-16',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 77299,
#    'cumCasesByPublishDate': 9420017,
#    'newDeaths28DaysByPublishDate': 122,
#    'cumDeaths28DaysByPublishDate': 127730},
#   {'date': '2021-12-15',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 68868,
#    'cumCasesByPublishDate': 9343520,
#    'newDeaths28DaysByPublishDate': 129,
#    'cumDeaths28DaysByPublishDate': 127608},
#   {'date': '2021-12-14',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 53093,
#    'cumCasesByPublishDate': 9275513,
#    'newDeaths28DaysByPublishDate': 138,
#    'cumDeaths28DaysByPublishDate': 127479},
#   {'date': '2021-12-13',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 44931,
#    'cumCasesByPublishDate': 9222932,
#    'newDeaths28DaysByPublishDate': 26,
#    'cumDeaths28DaysByPublishDate': 127341},
#   {'date': '2021-12-12',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 40713,
#    'cumCasesByPublishDate': 9178705,
#    'newDeaths28DaysByPublishDate': 44,
#    'cumDeaths28DaysByPublishDate': 127315},
#   {'date': '2021-12-11',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 48540,
#    'cumCasesByPublishDate': 9138773,
#    'newDeaths28DaysByPublishDate': 117,
#    'cumDeaths28DaysByPublishDate': 127271},
#   {'date': '2021-12-10',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 48908,
#    'cumCasesByPublishDate': 9092016,
#    'newDeaths28DaysByPublishDate': 90,
#    'cumDeaths28DaysByPublishDate': 127154},
#   {'date': '2021-12-09',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 43550,
#    'cumCasesByPublishDate': 9043108,
#    'newDeaths28DaysByPublishDate': 113,
#    'cumDeaths28DaysByPublishDate': 127064},
#   {'date': '2021-12-08',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 44019,
#    'cumCasesByPublishDate': 9000391,
#    'newDeaths28DaysByPublishDate': 134,
#    'cumDeaths28DaysByPublishDate': 126951},
#   {'date': '2021-12-07',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 38866,
#    'cumCasesByPublishDate': 8957091,
#    'newDeaths28DaysByPublishDate': 161,
#    'cumDeaths28DaysByPublishDate': 126817},
#   {'date': '2021-12-06',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 41525,
#    'cumCasesByPublishDate': 8918807,
#    'newDeaths28DaysByPublishDate': 34,
#    'cumDeaths28DaysByPublishDate': 126656},
#   {'date': '2021-12-05',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 37396,
#    'cumCasesByPublishDate': 8877883,
#    'newDeaths28DaysByPublishDate': 41,
#    'cumDeaths28DaysByPublishDate': 126622},
#   {'date': '2021-12-04',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 39949,
#    'cumCasesByPublishDate': 8841194,
#    'newDeaths28DaysByPublishDate': 104,
#    'cumDeaths28DaysByPublishDate': 126581},
#   {'date': '2021-12-03',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 43888,
#    'cumCasesByPublishDate': 8802632,
#    'newDeaths28DaysByPublishDate': 115,
#    'cumDeaths28DaysByPublishDate': 126477},
#   {'date': '2021-12-02',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 45880,
#    'cumCasesByPublishDate': 8758744,
#    'newDeaths28DaysByPublishDate': 104,
#    'cumDeaths28DaysByPublishDate': 126362},
#   {'date': '2021-12-01',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 41519,
#    'cumCasesByPublishDate': 8713738,
#    'newDeaths28DaysByPublishDate': 141,
#    'cumDeaths28DaysByPublishDate': 126258},
#   {'date': '2021-11-30',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 33590,
#    'cumCasesByPublishDate': 8673344,
#    'newDeaths28DaysByPublishDate': 143,
#    'cumDeaths28DaysByPublishDate': 126117},
#   {'date': '2021-11-29',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 34906,
#    'cumCasesByPublishDate': 8639754,
#    'newDeaths28DaysByPublishDate': 21,
#    'cumDeaths28DaysByPublishDate': 125974},
#   {'date': '2021-11-28',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 32136,
#    'cumCasesByPublishDate': 8605284,
#    'newDeaths28DaysByPublishDate': 40,
#    'cumDeaths28DaysByPublishDate': 125953},
#   {'date': '2021-11-27',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 35798,
#    'cumCasesByPublishDate': 8574315,
#    'newDeaths28DaysByPublishDate': 112,
#    'cumDeaths28DaysByPublishDate': 125913},
#   {'date': '2021-11-26',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 42272,
#    'cumCasesByPublishDate': 8538517,
#    'newDeaths28DaysByPublishDate': 125,
#    'cumDeaths28DaysByPublishDate': 125801},
#   {'date': '2021-11-25',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 40382,
#    'cumCasesByPublishDate': 8496990,
#    'newDeaths28DaysByPublishDate': 113,
#    'cumDeaths28DaysByPublishDate': 125676},
#   {'date': '2021-11-24',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 36511,
#    'cumCasesByPublishDate': 8457187,
#    'newDeaths28DaysByPublishDate': 129,
#    'cumDeaths28DaysByPublishDate': 125563},
#   {'date': '2021-11-23',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 36550,
#    'cumCasesByPublishDate': 8421911,
#    'newDeaths28DaysByPublishDate': 140,
#    'cumDeaths28DaysByPublishDate': 125434},
#   {'date': '2021-11-22',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 36478,
#    'cumCasesByPublishDate': 8385361,
#    'newDeaths28DaysByPublishDate': 34,
#    'cumDeaths28DaysByPublishDate': 125294},
#   {'date': '2021-11-21',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 33513,
#    'cumCasesByPublishDate': 8349363,
#    'newDeaths28DaysByPublishDate': 47,
#    'cumDeaths28DaysByPublishDate': 125260},
#   {'date': '2021-11-20',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 36339,
#    'cumCasesByPublishDate': 8316395,
#    'newDeaths28DaysByPublishDate': 133,
#    'cumDeaths28DaysByPublishDate': 125213},
#   {'date': '2021-11-19',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 37006,
#    'cumCasesByPublishDate': 8281117,
#    'newDeaths28DaysByPublishDate': 123,
#    'cumDeaths28DaysByPublishDate': 125080},
#   {'date': '2021-11-18',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 39315,
#    'cumCasesByPublishDate': 8244111,
#    'newDeaths28DaysByPublishDate': 144,
#    'cumDeaths28DaysByPublishDate': 124957},
#   {'date': '2021-11-17',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 30638,
#    'cumCasesByPublishDate': 8205448,
#    'newDeaths28DaysByPublishDate': 159,
#    'cumDeaths28DaysByPublishDate': 124813},
#   {'date': '2021-11-16',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 30853,
#    'cumCasesByPublishDate': 8175202,
#    'newDeaths28DaysByPublishDate': 190,
#    'cumDeaths28DaysByPublishDate': 124654},
#   {'date': '2021-11-15',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 31440,
#    'cumCasesByPublishDate': 8144766,
#    'newDeaths28DaysByPublishDate': 29,
#    'cumDeaths28DaysByPublishDate': 124464},
#   {'date': '2021-11-14',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 29404,
#    'cumCasesByPublishDate': 8113757,
#    'newDeaths28DaysByPublishDate': 51,
#    'cumDeaths28DaysByPublishDate': 124435},
#   {'date': '2021-11-13',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 33493,
#    'cumCasesByPublishDate': 8084740,
#    'newDeaths28DaysByPublishDate': 141,
#    'cumDeaths28DaysByPublishDate': 124384},
#   {'date': '2021-11-12',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 33155,
#    'cumCasesByPublishDate': 8051924,
#    'newDeaths28DaysByPublishDate': 122,
#    'cumDeaths28DaysByPublishDate': 124243},
#   {'date': '2021-11-11',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 35472,
#    'cumCasesByPublishDate': 8020241,
#    'newDeaths28DaysByPublishDate': 151,
#    'cumDeaths28DaysByPublishDate': 124121},
#   {'date': '2021-11-10',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 31541,
#    'cumCasesByPublishDate': 7984769,
#    'newDeaths28DaysByPublishDate': 170,
#    'cumDeaths28DaysByPublishDate': 123970},
#   {'date': '2021-11-09',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 27872,
#    'cumCasesByPublishDate': 7953228,
#    'newDeaths28DaysByPublishDate': 230,
#    'cumDeaths28DaysByPublishDate': 123800},
#   {'date': '2021-11-08',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 24979,
#    'cumCasesByPublishDate': 7925681,
#    'newDeaths28DaysByPublishDate': 32,
#    'cumDeaths28DaysByPublishDate': 123570},
#   {'date': '2021-11-07',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 23779,
#    'cumCasesByPublishDate': 7901039,
#    'newDeaths28DaysByPublishDate': 47,
#    'cumDeaths28DaysByPublishDate': 123538},
#   {'date': '2021-11-06',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 26250,
#    'cumCasesByPublishDate': 7877720,
#    'newDeaths28DaysByPublishDate': 125,
#    'cumDeaths28DaysByPublishDate': 123491},
#   {'date': '2021-11-05',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 28490,
#    'cumCasesByPublishDate': 7852005,
#    'newDeaths28DaysByPublishDate': 151,
#    'cumDeaths28DaysByPublishDate': 123366},
#   {'date': '2021-11-04',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 30166,
#    'cumCasesByPublishDate': 7823979,
#    'newDeaths28DaysByPublishDate': 152,
#    'cumDeaths28DaysByPublishDate': 123215},
#   {'date': '2021-11-03',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 34317,
#    'cumCasesByPublishDate': 7794507,
#    'newDeaths28DaysByPublishDate': 181,
#    'cumDeaths28DaysByPublishDate': 123063},
#   {'date': '2021-11-02',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 28531,
#    'cumCasesByPublishDate': 7760671,
#    'newDeaths28DaysByPublishDate': 255,
#    'cumDeaths28DaysByPublishDate': 122882},
#   {'date': '2021-11-01',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 32081,
#    'cumCasesByPublishDate': 7732441,
#    'newDeaths28DaysByPublishDate': 13,
#    'cumDeaths28DaysByPublishDate': 122627},
#   {'date': '2021-10-31',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 31479,
#    'cumCasesByPublishDate': 7700753,
#    'newDeaths28DaysByPublishDate': 59,
#    'cumDeaths28DaysByPublishDate': 122614},
#   {'date': '2021-10-30',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 36204,
#    'cumCasesByPublishDate': 7669614,
#    'newDeaths28DaysByPublishDate': 138,
#    'cumDeaths28DaysByPublishDate': 122555},
#   {'date': '2021-10-29',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 36853,
#    'cumCasesByPublishDate': 7633950,
#    'newDeaths28DaysByPublishDate': 148,
#    'cumDeaths28DaysByPublishDate': 122417},
#   {'date': '2021-10-28',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 33903,
#    'cumCasesByPublishDate': 7597473,
#    'newDeaths28DaysByPublishDate': 124,
#    'cumDeaths28DaysByPublishDate': 122269},
#   {'date': '2021-10-27',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 37502,
#    'cumCasesByPublishDate': 7564400,
#    'newDeaths28DaysByPublishDate': 169,
#    'cumDeaths28DaysByPublishDate': 122145},
#   {'date': '2021-10-26',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 32280,
#    'cumCasesByPublishDate': 7526898,
#    'newDeaths28DaysByPublishDate': 208,
#    'cumDeaths28DaysByPublishDate': 121976},
#   {'date': '2021-10-25',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 33309,
#    'cumCasesByPublishDate': 7494992,
#    'newDeaths28DaysByPublishDate': 34,
#    'cumDeaths28DaysByPublishDate': 121768},
#   {'date': '2021-10-24',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 33221,
#    'cumCasesByPublishDate': 7462144,
#    'newDeaths28DaysByPublishDate': 34,
#    'cumDeaths28DaysByPublishDate': 121734},
#   {'date': '2021-10-23',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 41259,
#    'cumCasesByPublishDate': 7430143,
#    'newDeaths28DaysByPublishDate': 125,
#    'cumDeaths28DaysByPublishDate': 121700},
#   {'date': '2021-10-22',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 41745,
#    'cumCasesByPublishDate': 7388884,
#    'newDeaths28DaysByPublishDate': 143,
#    'cumDeaths28DaysByPublishDate': 121575},
#   {'date': '2021-10-21',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 44363,
#    'cumCasesByPublishDate': 7347703,
#    'newDeaths28DaysByPublishDate': 66,
#    'cumDeaths28DaysByPublishDate': 121432},
#   {'date': '2021-10-20',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 41498,
#    'cumCasesByPublishDate': 7303864,
#    'newDeaths28DaysByPublishDate': 134,
#    'cumDeaths28DaysByPublishDate': 121366},
#   {'date': '2021-10-19',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 36712,
#    'cumCasesByPublishDate': 7262958,
#    'newDeaths28DaysByPublishDate': 189,
#    'cumDeaths28DaysByPublishDate': 121232},
#   {'date': '2021-10-18',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 39473,
#    'cumCasesByPublishDate': 7226658,
#    'newDeaths28DaysByPublishDate': 22,
#    'cumDeaths28DaysByPublishDate': 121043},
#   {'date': '2021-10-17',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 38543,
#    'cumCasesByPublishDate': 7187635,
#    'newDeaths28DaysByPublishDate': 41,
#    'cumDeaths28DaysByPublishDate': 121021},
#   {'date': '2021-10-16',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 39624,
#    'cumCasesByPublishDate': 7149533,
#    'newDeaths28DaysByPublishDate': 123,
#    'cumDeaths28DaysByPublishDate': 120980},
#   {'date': '2021-10-15',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 37691,
#    'cumCasesByPublishDate': 7110513,
#    'newDeaths28DaysByPublishDate': 94,
#    'cumDeaths28DaysByPublishDate': 120857},
#   {'date': '2021-10-14',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 38488,
#    'cumCasesByPublishDate': 7073467,
#    'newDeaths28DaysByPublishDate': 110,
#    'cumDeaths28DaysByPublishDate': 120763},
#   {'date': '2021-10-13',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 36458,
#    'cumCasesByPublishDate': 7035489,
#    'newDeaths28DaysByPublishDate': 101,
#    'cumDeaths28DaysByPublishDate': 120653},
#   {'date': '2021-10-12',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 33287,
#    'cumCasesByPublishDate': 7000356,
#    'newDeaths28DaysByPublishDate': 147,
#    'cumDeaths28DaysByPublishDate': 120552},
#   {'date': '2021-10-11',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 32349,
#    'cumCasesByPublishDate': 6967915,
#    'newDeaths28DaysByPublishDate': 15,
#    'cumDeaths28DaysByPublishDate': 120405},
#   {'date': '2021-10-10',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 31096,
#    'cumCasesByPublishDate': 6936327,
#    'newDeaths28DaysByPublishDate': 34,
#    'cumDeaths28DaysByPublishDate': 120390},
#   {'date': '2021-10-09',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 31259,
#    'cumCasesByPublishDate': 6906211,
#    'newDeaths28DaysByPublishDate': 111,
#    'cumDeaths28DaysByPublishDate': 120356},
#   {'date': '2021-10-08',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 32157,
#    'cumCasesByPublishDate': 6876192,
#    'newDeaths28DaysByPublishDate': 109,
#    'cumDeaths28DaysByPublishDate': 120245},
#   {'date': '2021-10-07',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 33305,
#    'cumCasesByPublishDate': 6845186,
#    'newDeaths28DaysByPublishDate': 71,
#    'cumDeaths28DaysByPublishDate': 120136},
#   {'date': '2021-10-06',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 33450,
#    'cumCasesByPublishDate': 6812848,
#    'newDeaths28DaysByPublishDate': 99,
#    'cumDeaths28DaysByPublishDate': 120065},
#   {'date': '2021-10-05',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 28846,
#    'cumCasesByPublishDate': 6780567,
#    'newDeaths28DaysByPublishDate': 140,
#    'cumDeaths28DaysByPublishDate': 119966},
#   {'date': '2021-10-04',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 28251,
#    'cumCasesByPublishDate': 6752536,
#    'newDeaths28DaysByPublishDate': 13,
#    'cumDeaths28DaysByPublishDate': 119826},
#   {'date': '2021-10-03',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 25176,
#    'cumCasesByPublishDate': 6725105,
#    'newDeaths28DaysByPublishDate': 30,
#    'cumDeaths28DaysByPublishDate': 119813},
#   {'date': '2021-10-02',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 26794,
#    'cumCasesByPublishDate': 6700702,
#    'newDeaths28DaysByPublishDate': 103,
#    'cumDeaths28DaysByPublishDate': 119783},
#   {'date': '2021-10-01',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 28836,
#    'cumCasesByPublishDate': 6674820,
#    'newDeaths28DaysByPublishDate': 80,
#    'cumDeaths28DaysByPublishDate': 119680},
#   {'date': '2021-09-30',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 29826,
#    'cumCasesByPublishDate': 6646963,
#    'newDeaths28DaysByPublishDate': 87,
#    'cumDeaths28DaysByPublishDate': 119600},
#   {'date': '2021-09-29',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 29036,
#    'cumCasesByPublishDate': 6617892,
#    'newDeaths28DaysByPublishDate': 111,
#    'cumDeaths28DaysByPublishDate': 119513},
#   {'date': '2021-09-28',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 28808,
#    'cumCasesByPublishDate': 6590514,
#    'newDeaths28DaysByPublishDate': 141,
#    'cumDeaths28DaysByPublishDate': 119402},
#   {'date': '2021-09-27',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 29329,
#    'cumCasesByPublishDate': 6561706,
#    'newDeaths28DaysByPublishDate': 23,
#    'cumDeaths28DaysByPublishDate': 119261},
#   {'date': '2021-09-26',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 25538,
#    'cumCasesByPublishDate': 6532847,
#    'newDeaths28DaysByPublishDate': 37,
#    'cumDeaths28DaysByPublishDate': 119238},
#   {'date': '2021-09-25',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 28087,
#    'cumCasesByPublishDate': 6507849,
#    'newDeaths28DaysByPublishDate': 104,
#    'cumDeaths28DaysByPublishDate': 119201},
#   {'date': '2021-09-24',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 28199,
#    'cumCasesByPublishDate': 6481363,
#    'newDeaths28DaysByPublishDate': 120,
#    'cumDeaths28DaysByPublishDate': 119097},
#   {'date': '2021-09-23',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 29045,
#    'cumCasesByPublishDate': 6453164,
#    'newDeaths28DaysByPublishDate': 131,
#    'cumDeaths28DaysByPublishDate': 118977},
#   {'date': '2021-09-22',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 27317,
#    'cumCasesByPublishDate': 6425056,
#    'newDeaths28DaysByPublishDate': 121,
#    'cumDeaths28DaysByPublishDate': 118846},
#   {'date': '2021-09-21',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 24973,
#    'cumCasesByPublishDate': 6398633,
#    'newDeaths28DaysByPublishDate': 174,
#    'cumDeaths28DaysByPublishDate': 118725},
#   {'date': '2021-09-20',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 26905,
#    'cumCasesByPublishDate': 6374123,
#    'newDeaths28DaysByPublishDate': 27,
#    'cumDeaths28DaysByPublishDate': 118551},
#   {'date': '2021-09-19',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 22173,
#    'cumCasesByPublishDate': 6347616,
#    'newDeaths28DaysByPublishDate': 34,
#    'cumDeaths28DaysByPublishDate': 118524},
#   {'date': '2021-09-18',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 22956,
#    'cumCasesByPublishDate': 6326046,
#    'newDeaths28DaysByPublishDate': 131,
#    'cumDeaths28DaysByPublishDate': 118490},
#   {'date': '2021-09-17',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 23265,
#    'cumCasesByPublishDate': 6303792,
#    'newDeaths28DaysByPublishDate': 130,
#    'cumDeaths28DaysByPublishDate': 118359},
#   {'date': '2021-09-16',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 22949,
#    'cumCasesByPublishDate': 6281236,
#    'newDeaths28DaysByPublishDate': 123,
#    'cumDeaths28DaysByPublishDate': 118229},
#   {'date': '2021-09-15',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 22078,
#    'cumCasesByPublishDate': 6258872,
#    'newDeaths28DaysByPublishDate': 151,
#    'cumDeaths28DaysByPublishDate': 118106},
#   {'date': '2021-09-14',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 19739,
#    'cumCasesByPublishDate': 6237505,
#    'newDeaths28DaysByPublishDate': 152,
#    'cumDeaths28DaysByPublishDate': 117955},
#   {'date': '2021-09-13',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 21077,
#    'cumCasesByPublishDate': 6218198,
#    'newDeaths28DaysByPublishDate': 32,
#    'cumDeaths28DaysByPublishDate': 117803},
#   {'date': '2021-09-12',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 19913,
#    'cumCasesByPublishDate': 6197654,
#    'newDeaths28DaysByPublishDate': 42,
#    'cumDeaths28DaysByPublishDate': 117771},
#   {'date': '2021-09-11',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 23825,
#    'cumCasesByPublishDate': 6178293,
#    'newDeaths28DaysByPublishDate': 143,
#    'cumDeaths28DaysByPublishDate': 117729},
#   {'date': '2021-09-10',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 26653,
#    'cumCasesByPublishDate': 6155149,
#    'newDeaths28DaysByPublishDate': 114,
#    'cumDeaths28DaysByPublishDate': 117586},
#   {'date': '2021-09-09',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 27049,
#    'cumCasesByPublishDate': 6129372,
#    'newDeaths28DaysByPublishDate': 138,
#    'cumDeaths28DaysByPublishDate': 117472},
#   {'date': '2021-09-08',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 29286,
#    'cumCasesByPublishDate': 6102850,
#    'newDeaths28DaysByPublishDate': 158,
#    'cumDeaths28DaysByPublishDate': 117334},
#   {'date': '2021-09-07',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 27545,
#    'cumCasesByPublishDate': 6074040,
#    'newDeaths28DaysByPublishDate': 183,
#    'cumDeaths28DaysByPublishDate': 117176},
#   {'date': '2021-09-06',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 27202,
#    'cumCasesByPublishDate': 6046799,
#    'newDeaths28DaysByPublishDate': 28,
#    'cumDeaths28DaysByPublishDate': 116993},
#   {'date': '2021-09-05',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 27022,
#    'cumCasesByPublishDate': 6019976,
#    'newDeaths28DaysByPublishDate': 58,
#    'cumDeaths28DaysByPublishDate': 116965},
#   {'date': '2021-09-04',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 29614,
#    'cumCasesByPublishDate': 5993444,
#    'newDeaths28DaysByPublishDate': 102,
#    'cumDeaths28DaysByPublishDate': 116907},
#   {'date': '2021-09-03',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 31726,
#    'cumCasesByPublishDate': 5964760,
#    'newDeaths28DaysByPublishDate': 96,
#    'cumDeaths28DaysByPublishDate': 116805},
#   {'date': '2021-09-02',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 28686,
#    'cumCasesByPublishDate': 5933034,
#    'newDeaths28DaysByPublishDate': 144,
#    'cumDeaths28DaysByPublishDate': 116709},
#   {'date': '2021-09-01',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 24723,
#    'cumCasesByPublishDate': 5904664,
#    'newDeaths28DaysByPublishDate': 184,
#    'cumDeaths28DaysByPublishDate': 116565},
#   {'date': '2021-08-31',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 20967,
#    'cumCasesByPublishDate': 5880134,
#    'newDeaths28DaysByPublishDate': 36,
#    'cumDeaths28DaysByPublishDate': 116381},
#   {'date': '2021-08-30',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 21324,
#    'cumCasesByPublishDate': 5859405,
#    'newDeaths28DaysByPublishDate': 42,
#    'cumDeaths28DaysByPublishDate': 116345},
#   {'date': '2021-08-29',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 22501,
#    'cumCasesByPublishDate': 5838323,
#    'newDeaths28DaysByPublishDate': 49,
#    'cumDeaths28DaysByPublishDate': 116303},
#   {'date': '2021-08-28',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 25118,
#    'cumCasesByPublishDate': 5816071,
#    'newDeaths28DaysByPublishDate': 119,
#    'cumDeaths28DaysByPublishDate': 116254},
#   {'date': '2021-08-27',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 27545,
#    'cumCasesByPublishDate': 5791272,
#    'newDeaths28DaysByPublishDate': 86,
#    'cumDeaths28DaysByPublishDate': 116135},
#   {'date': '2021-08-26',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 29417,
#    'cumCasesByPublishDate': 5764066,
#    'newDeaths28DaysByPublishDate': 121,
#    'cumDeaths28DaysByPublishDate': 116049},
#   {'date': '2021-08-25',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 27350,
#    'cumCasesByPublishDate': 5734967,
#    'newDeaths28DaysByPublishDate': 135,
#    'cumDeaths28DaysByPublishDate': 115928},
#   {'date': '2021-08-24',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 23474,
#    'cumCasesByPublishDate': 5707906,
#    'newDeaths28DaysByPublishDate': 152,
#    'cumDeaths28DaysByPublishDate': 115793},
#   {'date': '2021-08-23',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 24158,
#    'cumCasesByPublishDate': 5684645,
#    'newDeaths28DaysByPublishDate': 29,
#    'cumDeaths28DaysByPublishDate': 115641},
#   {'date': '2021-08-22',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 25952,
#    'cumCasesByPublishDate': 5660725,
#    'newDeaths28DaysByPublishDate': 33,
#    'cumDeaths28DaysByPublishDate': 115612},
#   {'date': '2021-08-21',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 26982,
#    'cumCasesByPublishDate': 5635046,
#    'newDeaths28DaysByPublishDate': 97,
#    'cumDeaths28DaysByPublishDate': 115579},
#   {'date': '2021-08-20',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 29576,
#    'cumCasesByPublishDate': 5608339,
#    'newDeaths28DaysByPublishDate': 92,
#    'cumDeaths28DaysByPublishDate': 115482},
#   {'date': '2021-08-19',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 29762,
#    'cumCasesByPublishDate': 5579087,
#    'newDeaths28DaysByPublishDate': 95,
#    'cumDeaths28DaysByPublishDate': 115390},
#   {'date': '2021-08-18',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 28648,
#    'cumCasesByPublishDate': 5549621,
#    'newDeaths28DaysByPublishDate': 86,
#    'cumDeaths28DaysByPublishDate': 115295},
#   {'date': '2021-08-17',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 22712,
#    'cumCasesByPublishDate': 5521231,
#    'newDeaths28DaysByPublishDate': 154,
#    'cumDeaths28DaysByPublishDate': 115209},
#   {'date': '2021-08-16',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 23171,
#    'cumCasesByPublishDate': 5498742,
#    'newDeaths28DaysByPublishDate': 20,
#    'cumDeaths28DaysByPublishDate': 115055},
#   {'date': '2021-08-15',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 22859,
#    'cumCasesByPublishDate': 5475833,
#    'newDeaths28DaysByPublishDate': 54,
#    'cumDeaths28DaysByPublishDate': 115035},
#   {'date': '2021-08-14',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 26700,
#    'cumCasesByPublishDate': 5453294,
#    'newDeaths28DaysByPublishDate': 83,
#    'cumDeaths28DaysByPublishDate': 114981},
#   {'date': '2021-08-13',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 28679,
#    'cumCasesByPublishDate': 5426971,
#    'newDeaths28DaysByPublishDate': 86,
#    'cumDeaths28DaysByPublishDate': 114898},
#   {'date': '2021-08-12',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 28093,
#    'cumCasesByPublishDate': 5398629,
#    'newDeaths28DaysByPublishDate': 81,
#    'cumDeaths28DaysByPublishDate': 114812},
#   {'date': '2021-08-11',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 26647,
#    'cumCasesByPublishDate': 5370904,
#    'newDeaths28DaysByPublishDate': 91,
#    'cumDeaths28DaysByPublishDate': 114731},
#   {'date': '2021-08-10',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 20630,
#    'cumCasesByPublishDate': 5344609,
#    'newDeaths28DaysByPublishDate': 132,
#    'cumDeaths28DaysByPublishDate': 114640},
#   {'date': '2021-08-09',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 21915,
#    'cumCasesByPublishDate': 5324191,
#    'newDeaths28DaysByPublishDate': 26,
#    'cumDeaths28DaysByPublishDate': 114508},
#   {'date': '2021-08-08',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 24196,
#    'cumCasesByPublishDate': 5302555,
#    'newDeaths28DaysByPublishDate': 35,
#    'cumDeaths28DaysByPublishDate': 114482},
#   {'date': '2021-08-07',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 25877,
#    'cumCasesByPublishDate': 5278675,
#    'newDeaths28DaysByPublishDate': 88,
#    'cumDeaths28DaysByPublishDate': 114447},
#   {'date': '2021-08-06',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 28321,
#    'cumCasesByPublishDate': 5253181,
#    'newDeaths28DaysByPublishDate': 81,
#    'cumDeaths28DaysByPublishDate': 114359},
#   {'date': '2021-08-05',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 26512,
#    'cumCasesByPublishDate': 5225224,
#    'newDeaths28DaysByPublishDate': 69,
#    'cumDeaths28DaysByPublishDate': 114278},
#   {'date': '2021-08-04',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 26393,
#    'cumCasesByPublishDate': 5199102,
#    'newDeaths28DaysByPublishDate': 101,
#    'cumDeaths28DaysByPublishDate': 114209},
#   {'date': '2021-08-03',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 19012,
#    'cumCasesByPublishDate': 5173082,
#    'newDeaths28DaysByPublishDate': 123,
#    'cumDeaths28DaysByPublishDate': 114108},
#   {'date': '2021-08-02',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 19175,
#    'cumCasesByPublishDate': 5154292,
#    'newDeaths28DaysByPublishDate': 17,
#    'cumDeaths28DaysByPublishDate': 113985},
#   {'date': '2021-08-01',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 21645,
#    'cumCasesByPublishDate': 5135378,
#    'newDeaths28DaysByPublishDate': 52,
#    'cumDeaths28DaysByPublishDate': 113968},
#   {'date': '2021-07-31',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 23949,
#    'cumCasesByPublishDate': 5114064,
#    'newDeaths28DaysByPublishDate': 54,
#    'cumDeaths28DaysByPublishDate': 113916},
#   {'date': '2021-07-30',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 26241,
#    'cumCasesByPublishDate': 5090505,
#    'newDeaths28DaysByPublishDate': 55,
#    'cumDeaths28DaysByPublishDate': 113862},
#   {'date': '2021-07-29',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 27524,
#    'cumCasesByPublishDate': 5064671,
#    'newDeaths28DaysByPublishDate': 67,
#    'cumDeaths28DaysByPublishDate': 113807},
#   {'date': '2021-07-28',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 24367,
#    'cumCasesByPublishDate': 5037630,
#    'newDeaths28DaysByPublishDate': 73,
#    'cumDeaths28DaysByPublishDate': 113740},
#   {'date': '2021-07-27',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 20290,
#    'cumCasesByPublishDate': 5013664,
#    'newDeaths28DaysByPublishDate': 121,
#    'cumDeaths28DaysByPublishDate': 113667},
#   {'date': '2021-07-26',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 22181,
#    'cumCasesByPublishDate': 4993657,
#    'newDeaths28DaysByPublishDate': 12,
#    'cumDeaths28DaysByPublishDate': 113546},
#   {'date': '2021-07-25',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 25434,
#    'cumCasesByPublishDate': 4972040,
#    'newDeaths28DaysByPublishDate': 26,
#    'cumDeaths28DaysByPublishDate': 113534},
#   {'date': '2021-07-24',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 28968,
#    'cumCasesByPublishDate': 4947127,
#    'newDeaths28DaysByPublishDate': 74,
#    'cumDeaths28DaysByPublishDate': 113508},
#   {'date': '2021-07-23',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 32792,
#    'cumCasesByPublishDate': 4918669,
#    'newDeaths28DaysByPublishDate': 56,
#    'cumDeaths28DaysByPublishDate': 113434},
#   {'date': '2021-07-22',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 35939,
#    'cumCasesByPublishDate': 4886612,
#    'newDeaths28DaysByPublishDate': 58,
#    'cumDeaths28DaysByPublishDate': 113378},
#   {'date': '2021-07-21',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 39504,
#    'cumCasesByPublishDate': 4851264,
#    'newDeaths28DaysByPublishDate': 63,
#    'cumDeaths28DaysByPublishDate': 113320},
#   {'date': '2021-07-20',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 43261,
#    'cumCasesByPublishDate': 4812460,
#    'newDeaths28DaysByPublishDate': 82,
#    'cumDeaths28DaysByPublishDate': 113257},
#   {'date': '2021-07-19',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 34657,
#    'cumCasesByPublishDate': 4769632,
#    'newDeaths28DaysByPublishDate': 15,
#    'cumDeaths28DaysByPublishDate': 113175},
#   {'date': '2021-07-18',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 44777,
#    'cumCasesByPublishDate': 4735387,
#    'newDeaths28DaysByPublishDate': 21,
#    'cumDeaths28DaysByPublishDate': 113160},
#   {'date': '2021-07-17',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 50955,
#    'cumCasesByPublishDate': 4691172,
#    'newDeaths28DaysByPublishDate': 35,
#    'cumDeaths28DaysByPublishDate': 113139},
#   {'date': '2021-07-16',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 47360,
#    'cumCasesByPublishDate': 4640922,
#    'newDeaths28DaysByPublishDate': 42,
#    'cumDeaths28DaysByPublishDate': 113104},
#   {'date': '2021-07-15',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 44523,
#    'cumCasesByPublishDate': 4594159,
#    'newDeaths28DaysByPublishDate': 44,
#    'cumDeaths28DaysByPublishDate': 113062},
#   {'date': '2021-07-14',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 37895,
#    'cumCasesByPublishDate': 4550298,
#    'newDeaths28DaysByPublishDate': 36,
#    'cumDeaths28DaysByPublishDate': 113018},
#   {'date': '2021-07-13',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 32883,
#    'cumCasesByPublishDate': 4512957,
#    'newDeaths28DaysByPublishDate': 45,
#    'cumDeaths28DaysByPublishDate': 112982},
#   {'date': '2021-07-12',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 30619,
#    'cumCasesByPublishDate': 4480518,
#    'newDeaths28DaysByPublishDate': 6,
#    'cumDeaths28DaysByPublishDate': 112937},
#   {'date': '2021-07-11',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 28421,
#    'cumCasesByPublishDate': 4450372,
#    'newDeaths28DaysByPublishDate': 25,
#    'cumDeaths28DaysByPublishDate': 112931},
#   {'date': '2021-07-10',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 29732,
#    'cumCasesByPublishDate': 4422370,
#    'newDeaths28DaysByPublishDate': 26,
#    'cumDeaths28DaysByPublishDate': 112906},
#   {'date': '2021-07-09',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 31231,
#    'cumCasesByPublishDate': 4393205,
#    'newDeaths28DaysByPublishDate': 22,
#    'cumDeaths28DaysByPublishDate': 112880},
#   {'date': '2021-07-08',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 28421,
#    'cumCasesByPublishDate': 4362481,
#    'newDeaths28DaysByPublishDate': 31,
#    'cumDeaths28DaysByPublishDate': 112858},
#   {'date': '2021-07-07',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 27516,
#    'cumCasesByPublishDate': 4334634,
#    'newDeaths28DaysByPublishDate': 28,
#    'cumDeaths28DaysByPublishDate': 112827},
#   {'date': '2021-07-06',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 25295,
#    'cumCasesByPublishDate': 4307618,
#    'newDeaths28DaysByPublishDate': 30,
#    'cumDeaths28DaysByPublishDate': 112799},
#   {'date': '2021-07-05',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 23286,
#    'cumCasesByPublishDate': 4282762,
#    'newDeaths28DaysByPublishDate': 7,
#    'cumDeaths28DaysByPublishDate': 112769},
#   {'date': '2021-07-04',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 20454,
#    'cumCasesByPublishDate': 4259710,
#    'newDeaths28DaysByPublishDate': 15,
#    'cumDeaths28DaysByPublishDate': 112762},
#   {'date': '2021-07-03',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 21317,
#    'cumCasesByPublishDate': 4239686,
#    'newDeaths28DaysByPublishDate': 15,
#    'cumDeaths28DaysByPublishDate': 112747},
#   {'date': '2021-07-02',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 22393,
#    'cumCasesByPublishDate': 4218807,
#    'newDeaths28DaysByPublishDate': 22,
#    'cumDeaths28DaysByPublishDate': 112732},
#   {'date': '2021-07-01',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 22948,
#    'cumCasesByPublishDate': 4196833,
#    'newDeaths28DaysByPublishDate': 16,
#    'cumDeaths28DaysByPublishDate': 112710},
#   {'date': '2021-06-30',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 21293,
#    'cumCasesByPublishDate': 4174318,
#    'newDeaths28DaysByPublishDate': 11,
#    'cumDeaths28DaysByPublishDate': 112694},
#   {'date': '2021-06-29',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 16802,
#    'cumCasesByPublishDate': 4153487,
#    'newDeaths28DaysByPublishDate': 22,
#    'cumDeaths28DaysByPublishDate': 112683},
#   {'date': '2021-06-28',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 18702,
#    'cumCasesByPublishDate': 4136940,
#    'newDeaths28DaysByPublishDate': 3,
#    'cumDeaths28DaysByPublishDate': 112661},
#   {'date': '2021-06-27',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 11560,
#    'cumCasesByPublishDate': 4118462,
#    'newDeaths28DaysByPublishDate': 9,
#    'cumDeaths28DaysByPublishDate': 112658},
#   {'date': '2021-06-26',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 15136,
#    'cumCasesByPublishDate': 4107155,
#    'newDeaths28DaysByPublishDate': 20,
#    'cumDeaths28DaysByPublishDate': 112649},
#   {'date': '2021-06-25',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 13498,
#    'cumCasesByPublishDate': 4092346,
#    'newDeaths28DaysByPublishDate': 15,
#    'cumDeaths28DaysByPublishDate': 112629},
#   {'date': '2021-06-24',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 13068,
#    'cumCasesByPublishDate': 4079362,
#    'newDeaths28DaysByPublishDate': 16,
#    'cumDeaths28DaysByPublishDate': 112614},
#   {'date': '2021-06-23',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 12765,
#    'cumCasesByPublishDate': 4066294,
#    'newDeaths28DaysByPublishDate': 13,
#    'cumDeaths28DaysByPublishDate': 112598},
#   {'date': '2021-06-22',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 9096,
#    'cumCasesByPublishDate': 4053782,
#    'newDeaths28DaysByPublishDate': 23,
#    'cumDeaths28DaysByPublishDate': 112585},
#   {'date': '2021-06-21',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 8766,
#    'cumCasesByPublishDate': 4044830,
#    'newDeaths28DaysByPublishDate': 5,
#    'cumDeaths28DaysByPublishDate': 112562},
#   {'date': '2021-06-20',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 7778,
#    'cumCasesByPublishDate': 4036230,
#    'newDeaths28DaysByPublishDate': 6,
#    'cumDeaths28DaysByPublishDate': 112557},
#   {'date': '2021-06-19',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 8954,
#    'cumCasesByPublishDate': 4028664,
#    'newDeaths28DaysByPublishDate': 12,
#    'cumDeaths28DaysByPublishDate': 112551},
#   {'date': '2021-06-18',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 9185,
#    'cumCasesByPublishDate': 4019956,
#    'newDeaths28DaysByPublishDate': 9,
#    'cumDeaths28DaysByPublishDate': 112539},
#   {'date': '2021-06-17',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 9371,
#    'cumCasesByPublishDate': 4010977,
#    'newDeaths28DaysByPublishDate': 15,
#    'cumDeaths28DaysByPublishDate': 112530},
#   {'date': '2021-06-16',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 7642,
#    'cumCasesByPublishDate': 4001803,
#    'newDeaths28DaysByPublishDate': 8,
#    'cumDeaths28DaysByPublishDate': 112515},
#   {'date': '2021-06-15',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 6486,
#    'cumCasesByPublishDate': 3994408,
#    'newDeaths28DaysByPublishDate': 8,
#    'cumDeaths28DaysByPublishDate': 112507},
#   {'date': '2021-06-14',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 6647,
#    'cumCasesByPublishDate': 3988008,
#    'newDeaths28DaysByPublishDate': 3,
#    'cumDeaths28DaysByPublishDate': 112499},
#   {'date': '2021-06-13',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 6269,
#    'cumCasesByPublishDate': 3981497,
#    'newDeaths28DaysByPublishDate': 7,
#    'cumDeaths28DaysByPublishDate': 112496},
#   {'date': '2021-06-12',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 6601,
#    'cumCasesByPublishDate': 3975399,
#    'newDeaths28DaysByPublishDate': 10,
#    'cumDeaths28DaysByPublishDate': 112489},
#   {'date': '2021-06-11',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 6782,
#    'cumCasesByPublishDate': 3968986,
#    'newDeaths28DaysByPublishDate': 16,
#    'cumDeaths28DaysByPublishDate': 112479},
#   {'date': '2021-06-10',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 6436,
#    'cumCasesByPublishDate': 3962371,
#    'newDeaths28DaysByPublishDate': 5,
#    'cumDeaths28DaysByPublishDate': 112463},
#   {'date': '2021-06-09',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 6201,
#    'cumCasesByPublishDate': 3956096,
#    'newDeaths28DaysByPublishDate': 5,
#    'cumDeaths28DaysByPublishDate': 112458},
#   {'date': '2021-06-08',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 5250,
#    'cumCasesByPublishDate': 3950123,
#    'newDeaths28DaysByPublishDate': 13,
#    'cumDeaths28DaysByPublishDate': 112453},
#   {'date': '2021-06-07',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 4913,
#    'cumCasesByPublishDate': 3944955,
#    'newDeaths28DaysByPublishDate': 0,
#    'cumDeaths28DaysByPublishDate': 112440},
#   {'date': '2021-06-06',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 4405,
#    'cumCasesByPublishDate': 3940141,
#    'newDeaths28DaysByPublishDate': 4,
#    'cumDeaths28DaysByPublishDate': 112440},
#   {'date': '2021-06-05',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 4810,
#    'cumCasesByPublishDate': 3935854,
#    'newDeaths28DaysByPublishDate': 12,
#    'cumDeaths28DaysByPublishDate': 112436},
#   {'date': '2021-06-04',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 5102,
#    'cumCasesByPublishDate': 3931158,
#    'newDeaths28DaysByPublishDate': 9,
#    'cumDeaths28DaysByPublishDate': 112424},
#   {'date': '2021-06-03',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 4310,
#    'cumCasesByPublishDate': 3926154,
#    'newDeaths28DaysByPublishDate': 13,
#    'cumDeaths28DaysByPublishDate': 112415},
#   {'date': '2021-06-02',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 3486,
#    'cumCasesByPublishDate': 3921939,
#    'newDeaths28DaysByPublishDate': 11,
#    'cumDeaths28DaysByPublishDate': 112402},
#   {'date': '2021-06-01',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 2539,
#    'cumCasesByPublishDate': 3918522,
#    'newDeaths28DaysByPublishDate': 0,
#    'cumDeaths28DaysByPublishDate': 112391},
#   {'date': '2021-05-31',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 2854,
#    'cumCasesByPublishDate': 3916049,
#    'newDeaths28DaysByPublishDate': 0,
#    'cumDeaths28DaysByPublishDate': 112391},
#   {'date': '2021-05-30',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 2621,
#    'cumCasesByPublishDate': 3913295,
#    'newDeaths28DaysByPublishDate': 6,
#    'cumDeaths28DaysByPublishDate': 112391},
#   {'date': '2021-05-29',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 2747,
#    'cumCasesByPublishDate': 3910803,
#    'newDeaths28DaysByPublishDate': 6,
#    'cumDeaths28DaysByPublishDate': 112385},
#   {'date': '2021-05-28',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 3434,
#    'cumCasesByPublishDate': 3908214,
#    'newDeaths28DaysByPublishDate': 8,
#    'cumDeaths28DaysByPublishDate': 112379},
#   {'date': '2021-05-27',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 2936,
#    'cumCasesByPublishDate': 3904934,
#    'newDeaths28DaysByPublishDate': 8,
#    'cumDeaths28DaysByPublishDate': 112371},
#   {'date': '2021-05-26',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 2540,
#    'cumCasesByPublishDate': 3902160,
#    'newDeaths28DaysByPublishDate': 8,
#    'cumDeaths28DaysByPublishDate': 112363},
#   {'date': '2021-05-25',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 2081,
#    'cumCasesByPublishDate': 3899813,
#    'newDeaths28DaysByPublishDate': 13,
#    'cumDeaths28DaysByPublishDate': 112355},
#   {'date': '2021-05-24',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 1972,
#    'cumCasesByPublishDate': 3897815,
#    'newDeaths28DaysByPublishDate': 3,
#    'cumDeaths28DaysByPublishDate': 112342},
#   {'date': '2021-05-23',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 1734,
#    'cumCasesByPublishDate': 3895920,
#    'newDeaths28DaysByPublishDate': 3,
# ...
#   {'date': '2020-04-05',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 5107,
#    'cumCasesByPublishDate': 39814,
#    'newDeaths28DaysByPublishDate': 578,
#    'cumDeaths28DaysByPublishDate': 5424},
#   {'date': '2020-04-04',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 2910,
#    'cumCasesByPublishDate': 34707,
#    'newDeaths28DaysByPublishDate': 689,
#    'cumDeaths28DaysByPublishDate': 4846},
#   {'date': '2020-04-03',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 3576,
#    'cumCasesByPublishDate': 31797,
#    'newDeaths28DaysByPublishDate': 654,
#    'cumDeaths28DaysByPublishDate': 4157},
#   {'date': '2020-04-02',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 3583,
#    'cumCasesByPublishDate': 28221,
#    'newDeaths28DaysByPublishDate': 603,
#    'cumDeaths28DaysByPublishDate': 3503},
#   {'date': '2020-04-01',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 3630,
#    'cumCasesByPublishDate': 24638,
#    'newDeaths28DaysByPublishDate': 613,
#    'cumDeaths28DaysByPublishDate': 2900},
#   {'date': '2020-03-31',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 2414,
#    'cumCasesByPublishDate': 21008,
#    'newDeaths28DaysByPublishDate': 368,
#    'cumDeaths28DaysByPublishDate': 2287},
#   {'date': '2020-03-30',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 2107,
#    'cumCasesByPublishDate': 18594,
#    'newDeaths28DaysByPublishDate': 353,
#    'cumDeaths28DaysByPublishDate': 1919},
#   {'date': '2020-03-29',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 2060,
#    'cumCasesByPublishDate': 16487,
#    'newDeaths28DaysByPublishDate': 195,
#    'cumDeaths28DaysByPublishDate': 1566},
#   {'date': '2020-03-28',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 2139,
#    'cumCasesByPublishDate': 14427,
#    'newDeaths28DaysByPublishDate': 279,
#    'cumDeaths28DaysByPublishDate': 1371},
#   {'date': '2020-03-27',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 2506,
#    'cumCasesByPublishDate': 12288,
#    'newDeaths28DaysByPublishDate': 271,
#    'cumDeaths28DaysByPublishDate': 1092},
#   {'date': '2020-03-26',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 1809,
#    'cumCasesByPublishDate': 9782,
#    'newDeaths28DaysByPublishDate': 169,
#    'cumDeaths28DaysByPublishDate': 821},
#   {'date': '2020-03-25',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 1130,
#    'cumCasesByPublishDate': 7973,
#    'newDeaths28DaysByPublishDate': 178,
#    'cumDeaths28DaysByPublishDate': 652},
#   {'date': '2020-03-24',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 1258,
#    'cumCasesByPublishDate': 6843,
#    'newDeaths28DaysByPublishDate': 143,
#    'cumDeaths28DaysByPublishDate': 474},
#   {'date': '2020-03-23',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 793,
#    'cumCasesByPublishDate': 5585,
#    'newDeaths28DaysByPublishDate': 67,
#    'cumDeaths28DaysByPublishDate': 331},
#   {'date': '2020-03-22',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 535,
#    'cumCasesByPublishDate': 4792,
#    'newDeaths28DaysByPublishDate': 24,
#    'cumDeaths28DaysByPublishDate': 264},
#   {'date': '2020-03-21',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 873,
#    'cumCasesByPublishDate': 4257,
#    'newDeaths28DaysByPublishDate': 54,
#    'cumDeaths28DaysByPublishDate': 240},
#   {'date': '2020-03-20',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 628,
#    'cumCasesByPublishDate': 3384,
#    'newDeaths28DaysByPublishDate': 32,
#    'cumDeaths28DaysByPublishDate': 186},
#   {'date': '2020-03-19',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 574,
#    'cumCasesByPublishDate': 2756,
#    'newDeaths28DaysByPublishDate': 42,
#    'cumDeaths28DaysByPublishDate': 154},
#   {'date': '2020-03-18',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 625,
#    'cumCasesByPublishDate': 2182,
#    'newDeaths28DaysByPublishDate': 33,
#    'cumDeaths28DaysByPublishDate': 112},
#   {'date': '2020-03-17',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 361,
#    'cumCasesByPublishDate': 1557,
#    'newDeaths28DaysByPublishDate': 15,
#    'cumDeaths28DaysByPublishDate': 79},
#   {'date': '2020-03-16',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 97,
#    'cumCasesByPublishDate': 1196,
#    'newDeaths28DaysByPublishDate': 22,
#    'cumDeaths28DaysByPublishDate': 64},
#   {'date': '2020-03-15',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 253,
#    'cumCasesByPublishDate': 1099,
#    'newDeaths28DaysByPublishDate': 14,
#    'cumDeaths28DaysByPublishDate': 42},
#   {'date': '2020-03-14',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 201,
#    'cumCasesByPublishDate': 846,
#    'newDeaths28DaysByPublishDate': 18,
#    'cumDeaths28DaysByPublishDate': 28},
#   {'date': '2020-03-13',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 159,
#    'cumCasesByPublishDate': 645,
#    'newDeaths28DaysByPublishDate': 1,
#    'cumDeaths28DaysByPublishDate': 10},
#   {'date': '2020-03-12',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 99,
#    'cumCasesByPublishDate': 486,
#    'newDeaths28DaysByPublishDate': 2,
#    'cumDeaths28DaysByPublishDate': 9},
#   {'date': '2020-03-11',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 63,
#    'cumCasesByPublishDate': 387,
#    'newDeaths28DaysByPublishDate': 0,
#    'cumDeaths28DaysByPublishDate': 7},
#   {'date': '2020-03-10',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 46,
#    'cumCasesByPublishDate': 324,
#    'newDeaths28DaysByPublishDate': 4,
#    'cumDeaths28DaysByPublishDate': 7},
#   {'date': '2020-03-09',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 40,
#    'cumCasesByPublishDate': 282,
#    'newDeaths28DaysByPublishDate': 1,
#    'cumDeaths28DaysByPublishDate': 3},
#   {'date': '2020-03-08',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 58,
#    'cumCasesByPublishDate': 241,
#    'newDeaths28DaysByPublishDate': 0,
#    'cumDeaths28DaysByPublishDate': 2},
#   {'date': '2020-03-07',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 39,
#    'cumCasesByPublishDate': 183,
#    'newDeaths28DaysByPublishDate': 1,
#    'cumDeaths28DaysByPublishDate': 2},
#   {'date': '2020-03-06',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 39,
#    'cumCasesByPublishDate': 144,
#    'newDeaths28DaysByPublishDate': 1,
#    'cumDeaths28DaysByPublishDate': 1},
#   {'date': '2020-03-05',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 25,
#    'cumCasesByPublishDate': 105,
#    'newDeaths28DaysByPublishDate': None,
#    'cumDeaths28DaysByPublishDate': None},
#   {'date': '2020-03-04',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 32,
#    'cumCasesByPublishDate': 80,
#    'newDeaths28DaysByPublishDate': None,
#    'cumDeaths28DaysByPublishDate': None},
#   {'date': '2020-03-03',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 11,
#    'cumCasesByPublishDate': 48,
#    'newDeaths28DaysByPublishDate': None,
#    'cumDeaths28DaysByPublishDate': None},
#   {'date': '2020-03-02',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 4,
#    'cumCasesByPublishDate': 37,
#    'newDeaths28DaysByPublishDate': None,
#    'cumDeaths28DaysByPublishDate': None},
#   {'date': '2020-03-01',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 12,
#    'cumCasesByPublishDate': 33,
#    'newDeaths28DaysByPublishDate': None,
#    'cumDeaths28DaysByPublishDate': None},
#   {'date': '2020-02-29',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 3,
#    'cumCasesByPublishDate': 21,
#    'newDeaths28DaysByPublishDate': None,
#    'cumDeaths28DaysByPublishDate': None},
#   {'date': '2020-02-28',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 5,
#    'cumCasesByPublishDate': 18,
#    'newDeaths28DaysByPublishDate': None,
#    'cumDeaths28DaysByPublishDate': None},
#   {'date': '2020-02-27',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 0,
#    'cumCasesByPublishDate': 13,
#    'newDeaths28DaysByPublishDate': None,
#    'cumDeaths28DaysByPublishDate': None},
#   {'date': '2020-02-26',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 0,
#    'cumCasesByPublishDate': 13,
#    'newDeaths28DaysByPublishDate': None,
#    'cumDeaths28DaysByPublishDate': None},
#   {'date': '2020-02-25',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 0,
#    'cumCasesByPublishDate': 13,
#    'newDeaths28DaysByPublishDate': None,
#    'cumDeaths28DaysByPublishDate': None},
#   {'date': '2020-02-24',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 4,
#    'cumCasesByPublishDate': 13,
#    'newDeaths28DaysByPublishDate': None,
#    'cumDeaths28DaysByPublishDate': None},
#   {'date': '2020-02-23',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 0,
#    'cumCasesByPublishDate': 9,
#    'newDeaths28DaysByPublishDate': None,
#    'cumDeaths28DaysByPublishDate': None},
#   {'date': '2020-02-22',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 0,
#    'cumCasesByPublishDate': 9,
#    'newDeaths28DaysByPublishDate': None,
#    'cumDeaths28DaysByPublishDate': None},
#   {'date': '2020-02-21',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 0,
#    'cumCasesByPublishDate': 9,
#    'newDeaths28DaysByPublishDate': None,
#    'cumDeaths28DaysByPublishDate': None},
#   {'date': '2020-02-20',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 0,
#    'cumCasesByPublishDate': 9,
#    'newDeaths28DaysByPublishDate': None,
#    'cumDeaths28DaysByPublishDate': None},
#   {'date': '2020-02-19',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 0,
#    'cumCasesByPublishDate': 9,
#    'newDeaths28DaysByPublishDate': None,
#    'cumDeaths28DaysByPublishDate': None},
#   {'date': '2020-02-18',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 0,
#    'cumCasesByPublishDate': 9,
#    'newDeaths28DaysByPublishDate': None,
#    'cumDeaths28DaysByPublishDate': None},
#   {'date': '2020-02-17',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 0,
#    'cumCasesByPublishDate': 9,
#    'newDeaths28DaysByPublishDate': None,
#    'cumDeaths28DaysByPublishDate': None},
#   {'date': '2020-02-16',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 0,
#    'cumCasesByPublishDate': 9,
#    'newDeaths28DaysByPublishDate': None,
#    'cumDeaths28DaysByPublishDate': None},
#   {'date': '2020-02-15',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 0,
#    'cumCasesByPublishDate': 9,
#    'newDeaths28DaysByPublishDate': None,
#    'cumDeaths28DaysByPublishDate': None},
#   {'date': '2020-02-14',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 0,
#    'cumCasesByPublishDate': 9,
#    'newDeaths28DaysByPublishDate': None,
#    'cumDeaths28DaysByPublishDate': None},
#   {'date': '2020-02-13',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 1,
#    'cumCasesByPublishDate': 9,
#    'newDeaths28DaysByPublishDate': None,
#    'cumDeaths28DaysByPublishDate': None},
#   {'date': '2020-02-12',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 0,
#    'cumCasesByPublishDate': 8,
#    'newDeaths28DaysByPublishDate': None,
#    'cumDeaths28DaysByPublishDate': None},
#   {'date': '2020-02-11',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 0,
#    'cumCasesByPublishDate': 8,
#    'newDeaths28DaysByPublishDate': None,
#    'cumDeaths28DaysByPublishDate': None},
#   {'date': '2020-02-10',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 4,
#    'cumCasesByPublishDate': 8,
#    'newDeaths28DaysByPublishDate': None,
#    'cumDeaths28DaysByPublishDate': None},
#   {'date': '2020-02-09',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 1,
#    'cumCasesByPublishDate': 4,
#    'newDeaths28DaysByPublishDate': None,
#    'cumDeaths28DaysByPublishDate': None},
#   {'date': '2020-02-08',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 0,
#    'cumCasesByPublishDate': 3,
#    'newDeaths28DaysByPublishDate': None,
#    'cumDeaths28DaysByPublishDate': None},
#   {'date': '2020-02-07',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 0,
#    'cumCasesByPublishDate': 3,
#    'newDeaths28DaysByPublishDate': None,
#    'cumDeaths28DaysByPublishDate': None},
#   {'date': '2020-02-06',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 1,
#    'cumCasesByPublishDate': 3,
#    'newDeaths28DaysByPublishDate': None,
#    'cumDeaths28DaysByPublishDate': None},
#   {'date': '2020-02-05',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 0,
#    'cumCasesByPublishDate': 2,
#    'newDeaths28DaysByPublishDate': None,
#    'cumDeaths28DaysByPublishDate': None},
#   {'date': '2020-02-04',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 0,
#    'cumCasesByPublishDate': 2,
#    'newDeaths28DaysByPublishDate': None,
#    'cumDeaths28DaysByPublishDate': None},
#   {'date': '2020-02-03',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 0,
#    'cumCasesByPublishDate': 2,
#    'newDeaths28DaysByPublishDate': None,
#    'cumDeaths28DaysByPublishDate': None},
#   {'date': '2020-02-02',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 0,
#    'cumCasesByPublishDate': 2,
#    'newDeaths28DaysByPublishDate': None,
#    'cumDeaths28DaysByPublishDate': None},
#   {'date': '2020-02-01',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 0,
#    'cumCasesByPublishDate': 2,
#    'newDeaths28DaysByPublishDate': None,
#    'cumDeaths28DaysByPublishDate': None},
#   {'date': '2020-01-31',
#    'name': 'England',
#    'code': 'E92000001',
#    'newCasesByPublishDate': 2,
#    'cumCasesByPublishDate': 2,
#    'newDeaths28DaysByPublishDate': None,
#    'cumDeaths28DaysByPublishDate': None}],
#  'requestPayload': {'structure': {'date': 'date',
#    'name': 'areaName',
#    'code': 'areaCode',
#    'newCasesByPublishDate': 'newCasesByPublishDate',
#    'cumCasesByPublishDate': 'cumCasesByPublishDate',
#    'newDeaths28DaysByPublishDate': 'newDeaths28DaysByPublishDate',
#    'cumDeaths28DaysByPublishDate': 'cumDeaths28DaysByPublishDate'},
#   'filters': [{'identifier': 'areaName', 'operator': '=', 'value': 'England'},
#    {'identifier': 'areaType', 'operator': '=', 'value': 'nation'}],
#   'page': 1},
#  'pagination': {'current': '/v1/data?filters=areaName=England;areaType=nation&structure={"date":"date","name":"areaName","code":"areaCode","newCasesByPublishDate":"newCasesByPublishDate","cumCasesByPublishDate":"cumCasesByPublishDate","newDeaths28DaysByPublishDate":"newDeaths28DaysByPublishDate","cumDeaths28DaysByPublishDate":"cumDeaths28DaysByPublishDate"}&format=json&page=1',
#   'next': None,
#   'previous': None,
#   'first': '/v1/data?filters=areaName=England;areaType=nation&structure={"date":"date","name":"areaName","code":"areaCode","newCasesByPublishDate":"newCasesByPublishDate","cumCasesByPublishDate":"cumCasesByPublishDate","newDeaths28DaysByPublishDate":"newDeaths28DaysByPublishDate","cumDeaths28DaysByPublishDate":"cumDeaths28DaysByPublishDate"}&format=json&page=1',
#   'last': '/v1/data?filters=areaName=England;areaType=nation&structure={"date":"date","name":"areaName","code":"areaCode","newCasesByPublishDate":"newCasesByPublishDate","cumCasesByPublishDate":"cumCasesByPublishDate","newDeaths28DaysByPublishDate":"newDeaths28DaysByPublishDate","cumDeaths28DaysByPublishDate":"cumDeaths28DaysByPublishDate"}&format=json&page=1'}}

# %%
json_object['data'][0]
# Out:
# {'date': '2021-12-20',
#  'name': 'England',
#  'code': 'E92000001',
#  'newCasesByPublishDate': 76065,
#  'cumCasesByPublishDate': 9731126,
#  'newDeaths28DaysByPublishDate': 35,
#  'cumDeaths28DaysByPublishDate': 128012}

# %%
full_list=[]
for each_dict in json_object['data'][:]:
    full_list.append(each_dict)

# %%
full_list
# Out:
# [{'date': '2021-12-20',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 76065,
#   'cumCasesByPublishDate': 9731126,
#   'newDeaths28DaysByPublishDate': 35,
#   'cumDeaths28DaysByPublishDate': 128012},
#  {'date': '2021-12-19',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 71702,
#   'cumCasesByPublishDate': 9655061,
#   'newDeaths28DaysByPublishDate': 38,
#   'cumDeaths28DaysByPublishDate': 127977},
#  {'date': '2021-12-18',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 82426,
#   'cumCasesByPublishDate': 9584269,
#   'newDeaths28DaysByPublishDate': 111,
#   'cumDeaths28DaysByPublishDate': 127939},
#  {'date': '2021-12-17',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 83693,
#   'cumCasesByPublishDate': 9503176,
#   'newDeaths28DaysByPublishDate': 98,
#   'cumDeaths28DaysByPublishDate': 127828},
#  {'date': '2021-12-16',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 77299,
#   'cumCasesByPublishDate': 9420017,
#   'newDeaths28DaysByPublishDate': 122,
#   'cumDeaths28DaysByPublishDate': 127730},
#  {'date': '2021-12-15',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 68868,
#   'cumCasesByPublishDate': 9343520,
#   'newDeaths28DaysByPublishDate': 129,
#   'cumDeaths28DaysByPublishDate': 127608},
#  {'date': '2021-12-14',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 53093,
#   'cumCasesByPublishDate': 9275513,
#   'newDeaths28DaysByPublishDate': 138,
#   'cumDeaths28DaysByPublishDate': 127479},
#  {'date': '2021-12-13',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 44931,
#   'cumCasesByPublishDate': 9222932,
#   'newDeaths28DaysByPublishDate': 26,
#   'cumDeaths28DaysByPublishDate': 127341},
#  {'date': '2021-12-12',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 40713,
#   'cumCasesByPublishDate': 9178705,
#   'newDeaths28DaysByPublishDate': 44,
#   'cumDeaths28DaysByPublishDate': 127315},
#  {'date': '2021-12-11',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 48540,
#   'cumCasesByPublishDate': 9138773,
#   'newDeaths28DaysByPublishDate': 117,
#   'cumDeaths28DaysByPublishDate': 127271},
#  {'date': '2021-12-10',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 48908,
#   'cumCasesByPublishDate': 9092016,
#   'newDeaths28DaysByPublishDate': 90,
#   'cumDeaths28DaysByPublishDate': 127154},
#  {'date': '2021-12-09',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 43550,
#   'cumCasesByPublishDate': 9043108,
#   'newDeaths28DaysByPublishDate': 113,
#   'cumDeaths28DaysByPublishDate': 127064},
#  {'date': '2021-12-08',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 44019,
#   'cumCasesByPublishDate': 9000391,
#   'newDeaths28DaysByPublishDate': 134,
#   'cumDeaths28DaysByPublishDate': 126951},
#  {'date': '2021-12-07',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 38866,
#   'cumCasesByPublishDate': 8957091,
#   'newDeaths28DaysByPublishDate': 161,
#   'cumDeaths28DaysByPublishDate': 126817},
#  {'date': '2021-12-06',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 41525,
#   'cumCasesByPublishDate': 8918807,
#   'newDeaths28DaysByPublishDate': 34,
#   'cumDeaths28DaysByPublishDate': 126656},
#  {'date': '2021-12-05',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 37396,
#   'cumCasesByPublishDate': 8877883,
#   'newDeaths28DaysByPublishDate': 41,
#   'cumDeaths28DaysByPublishDate': 126622},
#  {'date': '2021-12-04',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 39949,
#   'cumCasesByPublishDate': 8841194,
#   'newDeaths28DaysByPublishDate': 104,
#   'cumDeaths28DaysByPublishDate': 126581},
#  {'date': '2021-12-03',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 43888,
#   'cumCasesByPublishDate': 8802632,
#   'newDeaths28DaysByPublishDate': 115,
#   'cumDeaths28DaysByPublishDate': 126477},
#  {'date': '2021-12-02',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 45880,
#   'cumCasesByPublishDate': 8758744,
#   'newDeaths28DaysByPublishDate': 104,
#   'cumDeaths28DaysByPublishDate': 126362},
#  {'date': '2021-12-01',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 41519,
#   'cumCasesByPublishDate': 8713738,
#   'newDeaths28DaysByPublishDate': 141,
#   'cumDeaths28DaysByPublishDate': 126258},
#  {'date': '2021-11-30',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 33590,
#   'cumCasesByPublishDate': 8673344,
#   'newDeaths28DaysByPublishDate': 143,
#   'cumDeaths28DaysByPublishDate': 126117},
#  {'date': '2021-11-29',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 34906,
#   'cumCasesByPublishDate': 8639754,
#   'newDeaths28DaysByPublishDate': 21,
#   'cumDeaths28DaysByPublishDate': 125974},
#  {'date': '2021-11-28',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 32136,
#   'cumCasesByPublishDate': 8605284,
#   'newDeaths28DaysByPublishDate': 40,
#   'cumDeaths28DaysByPublishDate': 125953},
#  {'date': '2021-11-27',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 35798,
#   'cumCasesByPublishDate': 8574315,
#   'newDeaths28DaysByPublishDate': 112,
#   'cumDeaths28DaysByPublishDate': 125913},
#  {'date': '2021-11-26',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 42272,
#   'cumCasesByPublishDate': 8538517,
#   'newDeaths28DaysByPublishDate': 125,
#   'cumDeaths28DaysByPublishDate': 125801},
#  {'date': '2021-11-25',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 40382,
#   'cumCasesByPublishDate': 8496990,
#   'newDeaths28DaysByPublishDate': 113,
#   'cumDeaths28DaysByPublishDate': 125676},
#  {'date': '2021-11-24',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 36511,
#   'cumCasesByPublishDate': 8457187,
#   'newDeaths28DaysByPublishDate': 129,
#   'cumDeaths28DaysByPublishDate': 125563},
#  {'date': '2021-11-23',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 36550,
#   'cumCasesByPublishDate': 8421911,
#   'newDeaths28DaysByPublishDate': 140,
#   'cumDeaths28DaysByPublishDate': 125434},
#  {'date': '2021-11-22',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 36478,
#   'cumCasesByPublishDate': 8385361,
#   'newDeaths28DaysByPublishDate': 34,
#   'cumDeaths28DaysByPublishDate': 125294},
#  {'date': '2021-11-21',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 33513,
#   'cumCasesByPublishDate': 8349363,
#   'newDeaths28DaysByPublishDate': 47,
#   'cumDeaths28DaysByPublishDate': 125260},
#  {'date': '2021-11-20',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 36339,
#   'cumCasesByPublishDate': 8316395,
#   'newDeaths28DaysByPublishDate': 133,
#   'cumDeaths28DaysByPublishDate': 125213},
#  {'date': '2021-11-19',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 37006,
#   'cumCasesByPublishDate': 8281117,
#   'newDeaths28DaysByPublishDate': 123,
#   'cumDeaths28DaysByPublishDate': 125080},
#  {'date': '2021-11-18',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 39315,
#   'cumCasesByPublishDate': 8244111,
#   'newDeaths28DaysByPublishDate': 144,
#   'cumDeaths28DaysByPublishDate': 124957},
#  {'date': '2021-11-17',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 30638,
#   'cumCasesByPublishDate': 8205448,
#   'newDeaths28DaysByPublishDate': 159,
#   'cumDeaths28DaysByPublishDate': 124813},
#  {'date': '2021-11-16',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 30853,
#   'cumCasesByPublishDate': 8175202,
#   'newDeaths28DaysByPublishDate': 190,
#   'cumDeaths28DaysByPublishDate': 124654},
#  {'date': '2021-11-15',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 31440,
#   'cumCasesByPublishDate': 8144766,
#   'newDeaths28DaysByPublishDate': 29,
#   'cumDeaths28DaysByPublishDate': 124464},
#  {'date': '2021-11-14',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 29404,
#   'cumCasesByPublishDate': 8113757,
#   'newDeaths28DaysByPublishDate': 51,
#   'cumDeaths28DaysByPublishDate': 124435},
#  {'date': '2021-11-13',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 33493,
#   'cumCasesByPublishDate': 8084740,
#   'newDeaths28DaysByPublishDate': 141,
#   'cumDeaths28DaysByPublishDate': 124384},
#  {'date': '2021-11-12',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 33155,
#   'cumCasesByPublishDate': 8051924,
#   'newDeaths28DaysByPublishDate': 122,
#   'cumDeaths28DaysByPublishDate': 124243},
#  {'date': '2021-11-11',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 35472,
#   'cumCasesByPublishDate': 8020241,
#   'newDeaths28DaysByPublishDate': 151,
#   'cumDeaths28DaysByPublishDate': 124121},
#  {'date': '2021-11-10',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 31541,
#   'cumCasesByPublishDate': 7984769,
#   'newDeaths28DaysByPublishDate': 170,
#   'cumDeaths28DaysByPublishDate': 123970},
#  {'date': '2021-11-09',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 27872,
#   'cumCasesByPublishDate': 7953228,
#   'newDeaths28DaysByPublishDate': 230,
#   'cumDeaths28DaysByPublishDate': 123800},
#  {'date': '2021-11-08',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 24979,
#   'cumCasesByPublishDate': 7925681,
#   'newDeaths28DaysByPublishDate': 32,
#   'cumDeaths28DaysByPublishDate': 123570},
#  {'date': '2021-11-07',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 23779,
#   'cumCasesByPublishDate': 7901039,
#   'newDeaths28DaysByPublishDate': 47,
#   'cumDeaths28DaysByPublishDate': 123538},
#  {'date': '2021-11-06',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 26250,
#   'cumCasesByPublishDate': 7877720,
#   'newDeaths28DaysByPublishDate': 125,
#   'cumDeaths28DaysByPublishDate': 123491},
#  {'date': '2021-11-05',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 28490,
#   'cumCasesByPublishDate': 7852005,
#   'newDeaths28DaysByPublishDate': 151,
#   'cumDeaths28DaysByPublishDate': 123366},
#  {'date': '2021-11-04',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 30166,
#   'cumCasesByPublishDate': 7823979,
#   'newDeaths28DaysByPublishDate': 152,
#   'cumDeaths28DaysByPublishDate': 123215},
#  {'date': '2021-11-03',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 34317,
#   'cumCasesByPublishDate': 7794507,
#   'newDeaths28DaysByPublishDate': 181,
#   'cumDeaths28DaysByPublishDate': 123063},
#  {'date': '2021-11-02',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 28531,
#   'cumCasesByPublishDate': 7760671,
#   'newDeaths28DaysByPublishDate': 255,
#   'cumDeaths28DaysByPublishDate': 122882},
#  {'date': '2021-11-01',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 32081,
#   'cumCasesByPublishDate': 7732441,
#   'newDeaths28DaysByPublishDate': 13,
#   'cumDeaths28DaysByPublishDate': 122627},
#  {'date': '2021-10-31',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 31479,
#   'cumCasesByPublishDate': 7700753,
#   'newDeaths28DaysByPublishDate': 59,
#   'cumDeaths28DaysByPublishDate': 122614},
#  {'date': '2021-10-30',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 36204,
#   'cumCasesByPublishDate': 7669614,
#   'newDeaths28DaysByPublishDate': 138,
#   'cumDeaths28DaysByPublishDate': 122555},
#  {'date': '2021-10-29',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 36853,
#   'cumCasesByPublishDate': 7633950,
#   'newDeaths28DaysByPublishDate': 148,
#   'cumDeaths28DaysByPublishDate': 122417},
#  {'date': '2021-10-28',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 33903,
#   'cumCasesByPublishDate': 7597473,
#   'newDeaths28DaysByPublishDate': 124,
#   'cumDeaths28DaysByPublishDate': 122269},
#  {'date': '2021-10-27',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 37502,
#   'cumCasesByPublishDate': 7564400,
#   'newDeaths28DaysByPublishDate': 169,
#   'cumDeaths28DaysByPublishDate': 122145},
#  {'date': '2021-10-26',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 32280,
#   'cumCasesByPublishDate': 7526898,
#   'newDeaths28DaysByPublishDate': 208,
#   'cumDeaths28DaysByPublishDate': 121976},
#  {'date': '2021-10-25',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 33309,
#   'cumCasesByPublishDate': 7494992,
#   'newDeaths28DaysByPublishDate': 34,
#   'cumDeaths28DaysByPublishDate': 121768},
#  {'date': '2021-10-24',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 33221,
#   'cumCasesByPublishDate': 7462144,
#   'newDeaths28DaysByPublishDate': 34,
#   'cumDeaths28DaysByPublishDate': 121734},
#  {'date': '2021-10-23',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 41259,
#   'cumCasesByPublishDate': 7430143,
#   'newDeaths28DaysByPublishDate': 125,
#   'cumDeaths28DaysByPublishDate': 121700},
#  {'date': '2021-10-22',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 41745,
#   'cumCasesByPublishDate': 7388884,
#   'newDeaths28DaysByPublishDate': 143,
#   'cumDeaths28DaysByPublishDate': 121575},
#  {'date': '2021-10-21',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 44363,
#   'cumCasesByPublishDate': 7347703,
#   'newDeaths28DaysByPublishDate': 66,
#   'cumDeaths28DaysByPublishDate': 121432},
#  {'date': '2021-10-20',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 41498,
#   'cumCasesByPublishDate': 7303864,
#   'newDeaths28DaysByPublishDate': 134,
#   'cumDeaths28DaysByPublishDate': 121366},
#  {'date': '2021-10-19',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 36712,
#   'cumCasesByPublishDate': 7262958,
#   'newDeaths28DaysByPublishDate': 189,
#   'cumDeaths28DaysByPublishDate': 121232},
#  {'date': '2021-10-18',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 39473,
#   'cumCasesByPublishDate': 7226658,
#   'newDeaths28DaysByPublishDate': 22,
#   'cumDeaths28DaysByPublishDate': 121043},
#  {'date': '2021-10-17',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 38543,
#   'cumCasesByPublishDate': 7187635,
#   'newDeaths28DaysByPublishDate': 41,
#   'cumDeaths28DaysByPublishDate': 121021},
#  {'date': '2021-10-16',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 39624,
#   'cumCasesByPublishDate': 7149533,
#   'newDeaths28DaysByPublishDate': 123,
#   'cumDeaths28DaysByPublishDate': 120980},
#  {'date': '2021-10-15',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 37691,
#   'cumCasesByPublishDate': 7110513,
#   'newDeaths28DaysByPublishDate': 94,
#   'cumDeaths28DaysByPublishDate': 120857},
#  {'date': '2021-10-14',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 38488,
#   'cumCasesByPublishDate': 7073467,
#   'newDeaths28DaysByPublishDate': 110,
#   'cumDeaths28DaysByPublishDate': 120763},
#  {'date': '2021-10-13',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 36458,
#   'cumCasesByPublishDate': 7035489,
#   'newDeaths28DaysByPublishDate': 101,
#   'cumDeaths28DaysByPublishDate': 120653},
#  {'date': '2021-10-12',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 33287,
#   'cumCasesByPublishDate': 7000356,
#   'newDeaths28DaysByPublishDate': 147,
#   'cumDeaths28DaysByPublishDate': 120552},
#  {'date': '2021-10-11',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 32349,
#   'cumCasesByPublishDate': 6967915,
#   'newDeaths28DaysByPublishDate': 15,
#   'cumDeaths28DaysByPublishDate': 120405},
#  {'date': '2021-10-10',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 31096,
#   'cumCasesByPublishDate': 6936327,
#   'newDeaths28DaysByPublishDate': 34,
#   'cumDeaths28DaysByPublishDate': 120390},
#  {'date': '2021-10-09',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 31259,
#   'cumCasesByPublishDate': 6906211,
#   'newDeaths28DaysByPublishDate': 111,
#   'cumDeaths28DaysByPublishDate': 120356},
#  {'date': '2021-10-08',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 32157,
#   'cumCasesByPublishDate': 6876192,
#   'newDeaths28DaysByPublishDate': 109,
#   'cumDeaths28DaysByPublishDate': 120245},
#  {'date': '2021-10-07',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 33305,
#   'cumCasesByPublishDate': 6845186,
#   'newDeaths28DaysByPublishDate': 71,
#   'cumDeaths28DaysByPublishDate': 120136},
#  {'date': '2021-10-06',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 33450,
#   'cumCasesByPublishDate': 6812848,
#   'newDeaths28DaysByPublishDate': 99,
#   'cumDeaths28DaysByPublishDate': 120065},
#  {'date': '2021-10-05',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 28846,
#   'cumCasesByPublishDate': 6780567,
#   'newDeaths28DaysByPublishDate': 140,
#   'cumDeaths28DaysByPublishDate': 119966},
#  {'date': '2021-10-04',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 28251,
#   'cumCasesByPublishDate': 6752536,
#   'newDeaths28DaysByPublishDate': 13,
#   'cumDeaths28DaysByPublishDate': 119826},
#  {'date': '2021-10-03',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 25176,
#   'cumCasesByPublishDate': 6725105,
#   'newDeaths28DaysByPublishDate': 30,
#   'cumDeaths28DaysByPublishDate': 119813},
#  {'date': '2021-10-02',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 26794,
#   'cumCasesByPublishDate': 6700702,
#   'newDeaths28DaysByPublishDate': 103,
#   'cumDeaths28DaysByPublishDate': 119783},
#  {'date': '2021-10-01',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 28836,
#   'cumCasesByPublishDate': 6674820,
#   'newDeaths28DaysByPublishDate': 80,
#   'cumDeaths28DaysByPublishDate': 119680},
#  {'date': '2021-09-30',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 29826,
#   'cumCasesByPublishDate': 6646963,
#   'newDeaths28DaysByPublishDate': 87,
#   'cumDeaths28DaysByPublishDate': 119600},
#  {'date': '2021-09-29',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 29036,
#   'cumCasesByPublishDate': 6617892,
#   'newDeaths28DaysByPublishDate': 111,
#   'cumDeaths28DaysByPublishDate': 119513},
#  {'date': '2021-09-28',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 28808,
#   'cumCasesByPublishDate': 6590514,
#   'newDeaths28DaysByPublishDate': 141,
#   'cumDeaths28DaysByPublishDate': 119402},
#  {'date': '2021-09-27',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 29329,
#   'cumCasesByPublishDate': 6561706,
#   'newDeaths28DaysByPublishDate': 23,
#   'cumDeaths28DaysByPublishDate': 119261},
#  {'date': '2021-09-26',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 25538,
#   'cumCasesByPublishDate': 6532847,
#   'newDeaths28DaysByPublishDate': 37,
#   'cumDeaths28DaysByPublishDate': 119238},
#  {'date': '2021-09-25',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 28087,
#   'cumCasesByPublishDate': 6507849,
#   'newDeaths28DaysByPublishDate': 104,
#   'cumDeaths28DaysByPublishDate': 119201},
#  {'date': '2021-09-24',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 28199,
#   'cumCasesByPublishDate': 6481363,
#   'newDeaths28DaysByPublishDate': 120,
#   'cumDeaths28DaysByPublishDate': 119097},
#  {'date': '2021-09-23',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 29045,
#   'cumCasesByPublishDate': 6453164,
#   'newDeaths28DaysByPublishDate': 131,
#   'cumDeaths28DaysByPublishDate': 118977},
#  {'date': '2021-09-22',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 27317,
#   'cumCasesByPublishDate': 6425056,
#   'newDeaths28DaysByPublishDate': 121,
#   'cumDeaths28DaysByPublishDate': 118846},
#  {'date': '2021-09-21',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 24973,
#   'cumCasesByPublishDate': 6398633,
#   'newDeaths28DaysByPublishDate': 174,
#   'cumDeaths28DaysByPublishDate': 118725},
#  {'date': '2021-09-20',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 26905,
#   'cumCasesByPublishDate': 6374123,
#   'newDeaths28DaysByPublishDate': 27,
#   'cumDeaths28DaysByPublishDate': 118551},
#  {'date': '2021-09-19',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 22173,
#   'cumCasesByPublishDate': 6347616,
#   'newDeaths28DaysByPublishDate': 34,
#   'cumDeaths28DaysByPublishDate': 118524},
#  {'date': '2021-09-18',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 22956,
#   'cumCasesByPublishDate': 6326046,
#   'newDeaths28DaysByPublishDate': 131,
#   'cumDeaths28DaysByPublishDate': 118490},
#  {'date': '2021-09-17',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 23265,
#   'cumCasesByPublishDate': 6303792,
#   'newDeaths28DaysByPublishDate': 130,
#   'cumDeaths28DaysByPublishDate': 118359},
#  {'date': '2021-09-16',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 22949,
#   'cumCasesByPublishDate': 6281236,
#   'newDeaths28DaysByPublishDate': 123,
#   'cumDeaths28DaysByPublishDate': 118229},
#  {'date': '2021-09-15',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 22078,
#   'cumCasesByPublishDate': 6258872,
#   'newDeaths28DaysByPublishDate': 151,
#   'cumDeaths28DaysByPublishDate': 118106},
#  {'date': '2021-09-14',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 19739,
#   'cumCasesByPublishDate': 6237505,
#   'newDeaths28DaysByPublishDate': 152,
#   'cumDeaths28DaysByPublishDate': 117955},
#  {'date': '2021-09-13',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 21077,
#   'cumCasesByPublishDate': 6218198,
#   'newDeaths28DaysByPublishDate': 32,
#   'cumDeaths28DaysByPublishDate': 117803},
#  {'date': '2021-09-12',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 19913,
#   'cumCasesByPublishDate': 6197654,
#   'newDeaths28DaysByPublishDate': 42,
#   'cumDeaths28DaysByPublishDate': 117771},
#  {'date': '2021-09-11',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 23825,
#   'cumCasesByPublishDate': 6178293,
#   'newDeaths28DaysByPublishDate': 143,
#   'cumDeaths28DaysByPublishDate': 117729},
#  {'date': '2021-09-10',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 26653,
#   'cumCasesByPublishDate': 6155149,
#   'newDeaths28DaysByPublishDate': 114,
#   'cumDeaths28DaysByPublishDate': 117586},
#  {'date': '2021-09-09',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 27049,
#   'cumCasesByPublishDate': 6129372,
#   'newDeaths28DaysByPublishDate': 138,
#   'cumDeaths28DaysByPublishDate': 117472},
#  {'date': '2021-09-08',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 29286,
#   'cumCasesByPublishDate': 6102850,
#   'newDeaths28DaysByPublishDate': 158,
#   'cumDeaths28DaysByPublishDate': 117334},
#  {'date': '2021-09-07',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 27545,
#   'cumCasesByPublishDate': 6074040,
#   'newDeaths28DaysByPublishDate': 183,
#   'cumDeaths28DaysByPublishDate': 117176},
#  {'date': '2021-09-06',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 27202,
#   'cumCasesByPublishDate': 6046799,
#   'newDeaths28DaysByPublishDate': 28,
#   'cumDeaths28DaysByPublishDate': 116993},
#  {'date': '2021-09-05',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 27022,
#   'cumCasesByPublishDate': 6019976,
#   'newDeaths28DaysByPublishDate': 58,
#   'cumDeaths28DaysByPublishDate': 116965},
#  {'date': '2021-09-04',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 29614,
#   'cumCasesByPublishDate': 5993444,
#   'newDeaths28DaysByPublishDate': 102,
#   'cumDeaths28DaysByPublishDate': 116907},
#  {'date': '2021-09-03',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 31726,
#   'cumCasesByPublishDate': 5964760,
#   'newDeaths28DaysByPublishDate': 96,
#   'cumDeaths28DaysByPublishDate': 116805},
#  {'date': '2021-09-02',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 28686,
#   'cumCasesByPublishDate': 5933034,
#   'newDeaths28DaysByPublishDate': 144,
#   'cumDeaths28DaysByPublishDate': 116709},
#  {'date': '2021-09-01',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 24723,
#   'cumCasesByPublishDate': 5904664,
#   'newDeaths28DaysByPublishDate': 184,
#   'cumDeaths28DaysByPublishDate': 116565},
#  {'date': '2021-08-31',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 20967,
#   'cumCasesByPublishDate': 5880134,
#   'newDeaths28DaysByPublishDate': 36,
#   'cumDeaths28DaysByPublishDate': 116381},
#  {'date': '2021-08-30',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 21324,
#   'cumCasesByPublishDate': 5859405,
#   'newDeaths28DaysByPublishDate': 42,
#   'cumDeaths28DaysByPublishDate': 116345},
#  {'date': '2021-08-29',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 22501,
#   'cumCasesByPublishDate': 5838323,
#   'newDeaths28DaysByPublishDate': 49,
#   'cumDeaths28DaysByPublishDate': 116303},
#  {'date': '2021-08-28',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 25118,
#   'cumCasesByPublishDate': 5816071,
#   'newDeaths28DaysByPublishDate': 119,
#   'cumDeaths28DaysByPublishDate': 116254},
#  {'date': '2021-08-27',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 27545,
#   'cumCasesByPublishDate': 5791272,
#   'newDeaths28DaysByPublishDate': 86,
#   'cumDeaths28DaysByPublishDate': 116135},
#  {'date': '2021-08-26',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 29417,
#   'cumCasesByPublishDate': 5764066,
#   'newDeaths28DaysByPublishDate': 121,
#   'cumDeaths28DaysByPublishDate': 116049},
#  {'date': '2021-08-25',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 27350,
#   'cumCasesByPublishDate': 5734967,
#   'newDeaths28DaysByPublishDate': 135,
#   'cumDeaths28DaysByPublishDate': 115928},
#  {'date': '2021-08-24',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 23474,
#   'cumCasesByPublishDate': 5707906,
#   'newDeaths28DaysByPublishDate': 152,
#   'cumDeaths28DaysByPublishDate': 115793},
#  {'date': '2021-08-23',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 24158,
#   'cumCasesByPublishDate': 5684645,
#   'newDeaths28DaysByPublishDate': 29,
#   'cumDeaths28DaysByPublishDate': 115641},
#  {'date': '2021-08-22',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 25952,
#   'cumCasesByPublishDate': 5660725,
#   'newDeaths28DaysByPublishDate': 33,
#   'cumDeaths28DaysByPublishDate': 115612},
#  {'date': '2021-08-21',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 26982,
#   'cumCasesByPublishDate': 5635046,
#   'newDeaths28DaysByPublishDate': 97,
#   'cumDeaths28DaysByPublishDate': 115579},
#  {'date': '2021-08-20',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 29576,
#   'cumCasesByPublishDate': 5608339,
#   'newDeaths28DaysByPublishDate': 92,
#   'cumDeaths28DaysByPublishDate': 115482},
#  {'date': '2021-08-19',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 29762,
#   'cumCasesByPublishDate': 5579087,
#   'newDeaths28DaysByPublishDate': 95,
#   'cumDeaths28DaysByPublishDate': 115390},
#  {'date': '2021-08-18',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 28648,
#   'cumCasesByPublishDate': 5549621,
#   'newDeaths28DaysByPublishDate': 86,
#   'cumDeaths28DaysByPublishDate': 115295},
#  {'date': '2021-08-17',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 22712,
#   'cumCasesByPublishDate': 5521231,
#   'newDeaths28DaysByPublishDate': 154,
#   'cumDeaths28DaysByPublishDate': 115209},
#  {'date': '2021-08-16',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 23171,
#   'cumCasesByPublishDate': 5498742,
#   'newDeaths28DaysByPublishDate': 20,
#   'cumDeaths28DaysByPublishDate': 115055},
#  {'date': '2021-08-15',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 22859,
#   'cumCasesByPublishDate': 5475833,
#   'newDeaths28DaysByPublishDate': 54,
#   'cumDeaths28DaysByPublishDate': 115035},
#  {'date': '2021-08-14',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 26700,
#   'cumCasesByPublishDate': 5453294,
#   'newDeaths28DaysByPublishDate': 83,
#   'cumDeaths28DaysByPublishDate': 114981},
#  {'date': '2021-08-13',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 28679,
#   'cumCasesByPublishDate': 5426971,
#   'newDeaths28DaysByPublishDate': 86,
#   'cumDeaths28DaysByPublishDate': 114898},
#  {'date': '2021-08-12',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 28093,
#   'cumCasesByPublishDate': 5398629,
#   'newDeaths28DaysByPublishDate': 81,
#   'cumDeaths28DaysByPublishDate': 114812},
#  {'date': '2021-08-11',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 26647,
#   'cumCasesByPublishDate': 5370904,
#   'newDeaths28DaysByPublishDate': 91,
#   'cumDeaths28DaysByPublishDate': 114731},
#  {'date': '2021-08-10',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 20630,
#   'cumCasesByPublishDate': 5344609,
#   'newDeaths28DaysByPublishDate': 132,
#   'cumDeaths28DaysByPublishDate': 114640},
#  {'date': '2021-08-09',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 21915,
#   'cumCasesByPublishDate': 5324191,
#   'newDeaths28DaysByPublishDate': 26,
#   'cumDeaths28DaysByPublishDate': 114508},
#  {'date': '2021-08-08',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 24196,
#   'cumCasesByPublishDate': 5302555,
#   'newDeaths28DaysByPublishDate': 35,
#   'cumDeaths28DaysByPublishDate': 114482},
#  {'date': '2021-08-07',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 25877,
#   'cumCasesByPublishDate': 5278675,
#   'newDeaths28DaysByPublishDate': 88,
#   'cumDeaths28DaysByPublishDate': 114447},
#  {'date': '2021-08-06',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 28321,
#   'cumCasesByPublishDate': 5253181,
#   'newDeaths28DaysByPublishDate': 81,
#   'cumDeaths28DaysByPublishDate': 114359},
#  {'date': '2021-08-05',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 26512,
#   'cumCasesByPublishDate': 5225224,
#   'newDeaths28DaysByPublishDate': 69,
#   'cumDeaths28DaysByPublishDate': 114278},
#  {'date': '2021-08-04',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 26393,
#   'cumCasesByPublishDate': 5199102,
#   'newDeaths28DaysByPublishDate': 101,
#   'cumDeaths28DaysByPublishDate': 114209},
#  {'date': '2021-08-03',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 19012,
#   'cumCasesByPublishDate': 5173082,
#   'newDeaths28DaysByPublishDate': 123,
#   'cumDeaths28DaysByPublishDate': 114108},
#  {'date': '2021-08-02',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 19175,
#   'cumCasesByPublishDate': 5154292,
#   'newDeaths28DaysByPublishDate': 17,
#   'cumDeaths28DaysByPublishDate': 113985},
#  {'date': '2021-08-01',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 21645,
#   'cumCasesByPublishDate': 5135378,
#   'newDeaths28DaysByPublishDate': 52,
#   'cumDeaths28DaysByPublishDate': 113968},
#  {'date': '2021-07-31',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 23949,
#   'cumCasesByPublishDate': 5114064,
#   'newDeaths28DaysByPublishDate': 54,
#   'cumDeaths28DaysByPublishDate': 113916},
#  {'date': '2021-07-30',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 26241,
#   'cumCasesByPublishDate': 5090505,
#   'newDeaths28DaysByPublishDate': 55,
#   'cumDeaths28DaysByPublishDate': 113862},
#  {'date': '2021-07-29',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 27524,
#   'cumCasesByPublishDate': 5064671,
#   'newDeaths28DaysByPublishDate': 67,
#   'cumDeaths28DaysByPublishDate': 113807},
#  {'date': '2021-07-28',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 24367,
#   'cumCasesByPublishDate': 5037630,
#   'newDeaths28DaysByPublishDate': 73,
#   'cumDeaths28DaysByPublishDate': 113740},
#  {'date': '2021-07-27',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 20290,
#   'cumCasesByPublishDate': 5013664,
#   'newDeaths28DaysByPublishDate': 121,
#   'cumDeaths28DaysByPublishDate': 113667},
#  {'date': '2021-07-26',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 22181,
#   'cumCasesByPublishDate': 4993657,
#   'newDeaths28DaysByPublishDate': 12,
#   'cumDeaths28DaysByPublishDate': 113546},
#  {'date': '2021-07-25',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 25434,
#   'cumCasesByPublishDate': 4972040,
#   'newDeaths28DaysByPublishDate': 26,
#   'cumDeaths28DaysByPublishDate': 113534},
#  {'date': '2021-07-24',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 28968,
#   'cumCasesByPublishDate': 4947127,
#   'newDeaths28DaysByPublishDate': 74,
#   'cumDeaths28DaysByPublishDate': 113508},
#  {'date': '2021-07-23',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 32792,
#   'cumCasesByPublishDate': 4918669,
#   'newDeaths28DaysByPublishDate': 56,
#   'cumDeaths28DaysByPublishDate': 113434},
#  {'date': '2021-07-22',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 35939,
#   'cumCasesByPublishDate': 4886612,
#   'newDeaths28DaysByPublishDate': 58,
#   'cumDeaths28DaysByPublishDate': 113378},
#  {'date': '2021-07-21',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 39504,
#   'cumCasesByPublishDate': 4851264,
#   'newDeaths28DaysByPublishDate': 63,
#   'cumDeaths28DaysByPublishDate': 113320},
#  {'date': '2021-07-20',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 43261,
#   'cumCasesByPublishDate': 4812460,
#   'newDeaths28DaysByPublishDate': 82,
#   'cumDeaths28DaysByPublishDate': 113257},
#  {'date': '2021-07-19',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 34657,
#   'cumCasesByPublishDate': 4769632,
#   'newDeaths28DaysByPublishDate': 15,
#   'cumDeaths28DaysByPublishDate': 113175},
#  {'date': '2021-07-18',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 44777,
#   'cumCasesByPublishDate': 4735387,
#   'newDeaths28DaysByPublishDate': 21,
#   'cumDeaths28DaysByPublishDate': 113160},
#  {'date': '2021-07-17',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 50955,
#   'cumCasesByPublishDate': 4691172,
#   'newDeaths28DaysByPublishDate': 35,
#   'cumDeaths28DaysByPublishDate': 113139},
#  {'date': '2021-07-16',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 47360,
#   'cumCasesByPublishDate': 4640922,
#   'newDeaths28DaysByPublishDate': 42,
#   'cumDeaths28DaysByPublishDate': 113104},
#  {'date': '2021-07-15',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 44523,
#   'cumCasesByPublishDate': 4594159,
#   'newDeaths28DaysByPublishDate': 44,
#   'cumDeaths28DaysByPublishDate': 113062},
#  {'date': '2021-07-14',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 37895,
#   'cumCasesByPublishDate': 4550298,
#   'newDeaths28DaysByPublishDate': 36,
#   'cumDeaths28DaysByPublishDate': 113018},
#  {'date': '2021-07-13',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 32883,
#   'cumCasesByPublishDate': 4512957,
#   'newDeaths28DaysByPublishDate': 45,
#   'cumDeaths28DaysByPublishDate': 112982},
#  {'date': '2021-07-12',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 30619,
#   'cumCasesByPublishDate': 4480518,
#   'newDeaths28DaysByPublishDate': 6,
#   'cumDeaths28DaysByPublishDate': 112937},
#  {'date': '2021-07-11',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 28421,
#   'cumCasesByPublishDate': 4450372,
#   'newDeaths28DaysByPublishDate': 25,
#   'cumDeaths28DaysByPublishDate': 112931},
#  {'date': '2021-07-10',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 29732,
#   'cumCasesByPublishDate': 4422370,
#   'newDeaths28DaysByPublishDate': 26,
#   'cumDeaths28DaysByPublishDate': 112906},
#  {'date': '2021-07-09',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 31231,
#   'cumCasesByPublishDate': 4393205,
#   'newDeaths28DaysByPublishDate': 22,
#   'cumDeaths28DaysByPublishDate': 112880},
#  {'date': '2021-07-08',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 28421,
#   'cumCasesByPublishDate': 4362481,
#   'newDeaths28DaysByPublishDate': 31,
#   'cumDeaths28DaysByPublishDate': 112858},
#  {'date': '2021-07-07',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 27516,
#   'cumCasesByPublishDate': 4334634,
#   'newDeaths28DaysByPublishDate': 28,
#   'cumDeaths28DaysByPublishDate': 112827},
#  {'date': '2021-07-06',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 25295,
#   'cumCasesByPublishDate': 4307618,
#   'newDeaths28DaysByPublishDate': 30,
#   'cumDeaths28DaysByPublishDate': 112799},
#  {'date': '2021-07-05',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 23286,
#   'cumCasesByPublishDate': 4282762,
#   'newDeaths28DaysByPublishDate': 7,
#   'cumDeaths28DaysByPublishDate': 112769},
#  {'date': '2021-07-04',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 20454,
#   'cumCasesByPublishDate': 4259710,
#   'newDeaths28DaysByPublishDate': 15,
#   'cumDeaths28DaysByPublishDate': 112762},
#  {'date': '2021-07-03',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 21317,
#   'cumCasesByPublishDate': 4239686,
#   'newDeaths28DaysByPublishDate': 15,
#   'cumDeaths28DaysByPublishDate': 112747},
#  {'date': '2021-07-02',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 22393,
#   'cumCasesByPublishDate': 4218807,
#   'newDeaths28DaysByPublishDate': 22,
#   'cumDeaths28DaysByPublishDate': 112732},
#  {'date': '2021-07-01',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 22948,
#   'cumCasesByPublishDate': 4196833,
#   'newDeaths28DaysByPublishDate': 16,
#   'cumDeaths28DaysByPublishDate': 112710},
#  {'date': '2021-06-30',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 21293,
#   'cumCasesByPublishDate': 4174318,
#   'newDeaths28DaysByPublishDate': 11,
#   'cumDeaths28DaysByPublishDate': 112694},
#  {'date': '2021-06-29',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 16802,
#   'cumCasesByPublishDate': 4153487,
#   'newDeaths28DaysByPublishDate': 22,
#   'cumDeaths28DaysByPublishDate': 112683},
#  {'date': '2021-06-28',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 18702,
#   'cumCasesByPublishDate': 4136940,
#   'newDeaths28DaysByPublishDate': 3,
#   'cumDeaths28DaysByPublishDate': 112661},
#  {'date': '2021-06-27',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 11560,
#   'cumCasesByPublishDate': 4118462,
#   'newDeaths28DaysByPublishDate': 9,
#   'cumDeaths28DaysByPublishDate': 112658},
#  {'date': '2021-06-26',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 15136,
#   'cumCasesByPublishDate': 4107155,
#   'newDeaths28DaysByPublishDate': 20,
#   'cumDeaths28DaysByPublishDate': 112649},
#  {'date': '2021-06-25',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 13498,
#   'cumCasesByPublishDate': 4092346,
#   'newDeaths28DaysByPublishDate': 15,
#   'cumDeaths28DaysByPublishDate': 112629},
#  {'date': '2021-06-24',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 13068,
#   'cumCasesByPublishDate': 4079362,
#   'newDeaths28DaysByPublishDate': 16,
#   'cumDeaths28DaysByPublishDate': 112614},
#  {'date': '2021-06-23',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 12765,
#   'cumCasesByPublishDate': 4066294,
#   'newDeaths28DaysByPublishDate': 13,
#   'cumDeaths28DaysByPublishDate': 112598},
#  {'date': '2021-06-22',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 9096,
#   'cumCasesByPublishDate': 4053782,
#   'newDeaths28DaysByPublishDate': 23,
#   'cumDeaths28DaysByPublishDate': 112585},
#  {'date': '2021-06-21',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 8766,
#   'cumCasesByPublishDate': 4044830,
#   'newDeaths28DaysByPublishDate': 5,
#   'cumDeaths28DaysByPublishDate': 112562},
#  {'date': '2021-06-20',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 7778,
#   'cumCasesByPublishDate': 4036230,
#   'newDeaths28DaysByPublishDate': 6,
#   'cumDeaths28DaysByPublishDate': 112557},
#  {'date': '2021-06-19',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 8954,
#   'cumCasesByPublishDate': 4028664,
#   'newDeaths28DaysByPublishDate': 12,
#   'cumDeaths28DaysByPublishDate': 112551},
#  {'date': '2021-06-18',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 9185,
#   'cumCasesByPublishDate': 4019956,
#   'newDeaths28DaysByPublishDate': 9,
#   'cumDeaths28DaysByPublishDate': 112539},
#  {'date': '2021-06-17',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 9371,
#   'cumCasesByPublishDate': 4010977,
#   'newDeaths28DaysByPublishDate': 15,
#   'cumDeaths28DaysByPublishDate': 112530},
#  {'date': '2021-06-16',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 7642,
#   'cumCasesByPublishDate': 4001803,
#   'newDeaths28DaysByPublishDate': 8,
#   'cumDeaths28DaysByPublishDate': 112515},
#  {'date': '2021-06-15',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 6486,
#   'cumCasesByPublishDate': 3994408,
#   'newDeaths28DaysByPublishDate': 8,
#   'cumDeaths28DaysByPublishDate': 112507},
#  {'date': '2021-06-14',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 6647,
#   'cumCasesByPublishDate': 3988008,
#   'newDeaths28DaysByPublishDate': 3,
#   'cumDeaths28DaysByPublishDate': 112499},
#  {'date': '2021-06-13',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 6269,
#   'cumCasesByPublishDate': 3981497,
#   'newDeaths28DaysByPublishDate': 7,
#   'cumDeaths28DaysByPublishDate': 112496},
#  {'date': '2021-06-12',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 6601,
#   'cumCasesByPublishDate': 3975399,
#   'newDeaths28DaysByPublishDate': 10,
#   'cumDeaths28DaysByPublishDate': 112489},
#  {'date': '2021-06-11',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 6782,
#   'cumCasesByPublishDate': 3968986,
#   'newDeaths28DaysByPublishDate': 16,
#   'cumDeaths28DaysByPublishDate': 112479},
#  {'date': '2021-06-10',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 6436,
#   'cumCasesByPublishDate': 3962371,
#   'newDeaths28DaysByPublishDate': 5,
#   'cumDeaths28DaysByPublishDate': 112463},
#  {'date': '2021-06-09',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 6201,
#   'cumCasesByPublishDate': 3956096,
#   'newDeaths28DaysByPublishDate': 5,
#   'cumDeaths28DaysByPublishDate': 112458},
#  {'date': '2021-06-08',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 5250,
#   'cumCasesByPublishDate': 3950123,
#   'newDeaths28DaysByPublishDate': 13,
#   'cumDeaths28DaysByPublishDate': 112453},
#  {'date': '2021-06-07',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 4913,
#   'cumCasesByPublishDate': 3944955,
#   'newDeaths28DaysByPublishDate': 0,
#   'cumDeaths28DaysByPublishDate': 112440},
#  {'date': '2021-06-06',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 4405,
#   'cumCasesByPublishDate': 3940141,
#   'newDeaths28DaysByPublishDate': 4,
#   'cumDeaths28DaysByPublishDate': 112440},
#  {'date': '2021-06-05',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 4810,
#   'cumCasesByPublishDate': 3935854,
#   'newDeaths28DaysByPublishDate': 12,
#   'cumDeaths28DaysByPublishDate': 112436},
#  {'date': '2021-06-04',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 5102,
#   'cumCasesByPublishDate': 3931158,
#   'newDeaths28DaysByPublishDate': 9,
#   'cumDeaths28DaysByPublishDate': 112424},
#  {'date': '2021-06-03',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 4310,
#   'cumCasesByPublishDate': 3926154,
#   'newDeaths28DaysByPublishDate': 13,
#   'cumDeaths28DaysByPublishDate': 112415},
#  {'date': '2021-06-02',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 3486,
#   'cumCasesByPublishDate': 3921939,
#   'newDeaths28DaysByPublishDate': 11,
#   'cumDeaths28DaysByPublishDate': 112402},
#  {'date': '2021-06-01',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 2539,
#   'cumCasesByPublishDate': 3918522,
#   'newDeaths28DaysByPublishDate': 0,
#   'cumDeaths28DaysByPublishDate': 112391},
#  {'date': '2021-05-31',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 2854,
#   'cumCasesByPublishDate': 3916049,
#   'newDeaths28DaysByPublishDate': 0,
#   'cumDeaths28DaysByPublishDate': 112391},
#  {'date': '2021-05-30',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 2621,
#   'cumCasesByPublishDate': 3913295,
#   'newDeaths28DaysByPublishDate': 6,
#   'cumDeaths28DaysByPublishDate': 112391},
#  {'date': '2021-05-29',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 2747,
#   'cumCasesByPublishDate': 3910803,
#   'newDeaths28DaysByPublishDate': 6,
#   'cumDeaths28DaysByPublishDate': 112385},
#  {'date': '2021-05-28',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 3434,
#   'cumCasesByPublishDate': 3908214,
#   'newDeaths28DaysByPublishDate': 8,
#   'cumDeaths28DaysByPublishDate': 112379},
#  {'date': '2021-05-27',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 2936,
#   'cumCasesByPublishDate': 3904934,
#   'newDeaths28DaysByPublishDate': 8,
#   'cumDeaths28DaysByPublishDate': 112371},
#  {'date': '2021-05-26',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 2540,
#   'cumCasesByPublishDate': 3902160,
#   'newDeaths28DaysByPublishDate': 8,
#   'cumDeaths28DaysByPublishDate': 112363},
#  {'date': '2021-05-25',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 2081,
#   'cumCasesByPublishDate': 3899813,
#   'newDeaths28DaysByPublishDate': 13,
#   'cumDeaths28DaysByPublishDate': 112355},
#  {'date': '2021-05-24',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 1972,
#   'cumCasesByPublishDate': 3897815,
#   'newDeaths28DaysByPublishDate': 3,
#   'cumDeaths28DaysByPublishDate': 112342},
#  {'date': '2021-05-23',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 1734,
#   'cumCasesByPublishDate': 3895920,
#   'newDeaths28DaysByPublishDate': 3,
#   'cumDeaths28DaysByPublishDate': 112339},
#  {'date': '2021-05-22',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 2242,
#   'cumCasesByPublishDate': 3894329,
#   'newDeaths28DaysByPublishDate': 6,
#   'cumDeaths28DaysByPublishDate': 112336},
#  {'date': '2021-05-21',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 2303,
#   'cumCasesByPublishDate': 3892258,
#   'newDeaths28DaysByPublishDate': 6,
#   'cumDeaths28DaysByPublishDate': 112330},
#  {'date': '2021-05-20',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 2307,
#   'cumCasesByPublishDate': 3890081,
#   'newDeaths28DaysByPublishDate': 6,
#   'cumDeaths28DaysByPublishDate': 112324},
#  {'date': '2021-05-19',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 2151,
#   'cumCasesByPublishDate': 3887954,
#   'newDeaths28DaysByPublishDate': 3,
#   'cumDeaths28DaysByPublishDate': 112318},
#  {'date': '2021-05-18',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 2008,
#   'cumCasesByPublishDate': 3886364,
#   'newDeaths28DaysByPublishDate': 5,
#   'cumDeaths28DaysByPublishDate': 112315},
#  {'date': '2021-05-17',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 1645,
#   'cumCasesByPublishDate': 3889132,
#   'newDeaths28DaysByPublishDate': 3,
#   'cumDeaths28DaysByPublishDate': 112310},
#  {'date': '2021-05-16',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 1471,
#   'cumCasesByPublishDate': 3887487,
#   'newDeaths28DaysByPublishDate': 3,
#   'cumDeaths28DaysByPublishDate': 112307},
#  {'date': '2021-05-15',
# ...
#   'code': 'E92000001',
#   'newCasesByPublishDate': 3188,
#   'cumCasesByPublishDate': 76371,
#   'newDeaths28DaysByPublishDate': 730,
#   'cumDeaths28DaysByPublishDate': 13691},
#  {'date': '2020-04-14',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 3854,
#   'cumCasesByPublishDate': 73183,
#   'newDeaths28DaysByPublishDate': 1007,
#   'cumDeaths28DaysByPublishDate': 12961},
#  {'date': '2020-04-13',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 2999,
#   'cumCasesByPublishDate': 69329,
#   'newDeaths28DaysByPublishDate': 694,
#   'cumDeaths28DaysByPublishDate': 11954},
#  {'date': '2020-04-12',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 3672,
#   'cumCasesByPublishDate': 66330,
#   'newDeaths28DaysByPublishDate': 604,
#   'cumDeaths28DaysByPublishDate': 11260},
#  {'date': '2020-04-11',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 3841,
#   'cumCasesByPublishDate': 62658,
#   'newDeaths28DaysByPublishDate': 745,
#   'cumDeaths28DaysByPublishDate': 10656},
#  {'date': '2020-04-10',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 4263,
#   'cumCasesByPublishDate': 58817,
#   'newDeaths28DaysByPublishDate': 1035,
#   'cumDeaths28DaysByPublishDate': 9911},
#  {'date': '2020-04-09',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 3798,
#   'cumCasesByPublishDate': 54554,
#   'newDeaths28DaysByPublishDate': 990,
#   'cumDeaths28DaysByPublishDate': 8876},
#  {'date': '2020-04-08',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 4788,
#   'cumCasesByPublishDate': 50756,
#   'newDeaths28DaysByPublishDate': 922,
#   'cumDeaths28DaysByPublishDate': 7886},
#  {'date': '2020-04-07',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 2978,
#   'cumCasesByPublishDate': 45968,
#   'newDeaths28DaysByPublishDate': 1009,
#   'cumDeaths28DaysByPublishDate': 6964},
#  {'date': '2020-04-06',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 3176,
#   'cumCasesByPublishDate': 42990,
#   'newDeaths28DaysByPublishDate': 531,
#   'cumDeaths28DaysByPublishDate': 5955},
#  {'date': '2020-04-05',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 5107,
#   'cumCasesByPublishDate': 39814,
#   'newDeaths28DaysByPublishDate': 578,
#   'cumDeaths28DaysByPublishDate': 5424},
#  {'date': '2020-04-04',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 2910,
#   'cumCasesByPublishDate': 34707,
#   'newDeaths28DaysByPublishDate': 689,
#   'cumDeaths28DaysByPublishDate': 4846},
#  {'date': '2020-04-03',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 3576,
#   'cumCasesByPublishDate': 31797,
#   'newDeaths28DaysByPublishDate': 654,
#   'cumDeaths28DaysByPublishDate': 4157},
#  {'date': '2020-04-02',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 3583,
#   'cumCasesByPublishDate': 28221,
#   'newDeaths28DaysByPublishDate': 603,
#   'cumDeaths28DaysByPublishDate': 3503},
#  {'date': '2020-04-01',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 3630,
#   'cumCasesByPublishDate': 24638,
#   'newDeaths28DaysByPublishDate': 613,
#   'cumDeaths28DaysByPublishDate': 2900},
#  {'date': '2020-03-31',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 2414,
#   'cumCasesByPublishDate': 21008,
#   'newDeaths28DaysByPublishDate': 368,
#   'cumDeaths28DaysByPublishDate': 2287},
#  {'date': '2020-03-30',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 2107,
#   'cumCasesByPublishDate': 18594,
#   'newDeaths28DaysByPublishDate': 353,
#   'cumDeaths28DaysByPublishDate': 1919},
#  {'date': '2020-03-29',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 2060,
#   'cumCasesByPublishDate': 16487,
#   'newDeaths28DaysByPublishDate': 195,
#   'cumDeaths28DaysByPublishDate': 1566},
#  {'date': '2020-03-28',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 2139,
#   'cumCasesByPublishDate': 14427,
#   'newDeaths28DaysByPublishDate': 279,
#   'cumDeaths28DaysByPublishDate': 1371},
#  {'date': '2020-03-27',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 2506,
#   'cumCasesByPublishDate': 12288,
#   'newDeaths28DaysByPublishDate': 271,
#   'cumDeaths28DaysByPublishDate': 1092},
#  {'date': '2020-03-26',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 1809,
#   'cumCasesByPublishDate': 9782,
#   'newDeaths28DaysByPublishDate': 169,
#   'cumDeaths28DaysByPublishDate': 821},
#  {'date': '2020-03-25',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 1130,
#   'cumCasesByPublishDate': 7973,
#   'newDeaths28DaysByPublishDate': 178,
#   'cumDeaths28DaysByPublishDate': 652},
#  {'date': '2020-03-24',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 1258,
#   'cumCasesByPublishDate': 6843,
#   'newDeaths28DaysByPublishDate': 143,
#   'cumDeaths28DaysByPublishDate': 474},
#  {'date': '2020-03-23',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 793,
#   'cumCasesByPublishDate': 5585,
#   'newDeaths28DaysByPublishDate': 67,
#   'cumDeaths28DaysByPublishDate': 331},
#  {'date': '2020-03-22',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 535,
#   'cumCasesByPublishDate': 4792,
#   'newDeaths28DaysByPublishDate': 24,
#   'cumDeaths28DaysByPublishDate': 264},
#  {'date': '2020-03-21',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 873,
#   'cumCasesByPublishDate': 4257,
#   'newDeaths28DaysByPublishDate': 54,
#   'cumDeaths28DaysByPublishDate': 240},
#  {'date': '2020-03-20',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 628,
#   'cumCasesByPublishDate': 3384,
#   'newDeaths28DaysByPublishDate': 32,
#   'cumDeaths28DaysByPublishDate': 186},
#  {'date': '2020-03-19',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 574,
#   'cumCasesByPublishDate': 2756,
#   'newDeaths28DaysByPublishDate': 42,
#   'cumDeaths28DaysByPublishDate': 154},
#  {'date': '2020-03-18',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 625,
#   'cumCasesByPublishDate': 2182,
#   'newDeaths28DaysByPublishDate': 33,
#   'cumDeaths28DaysByPublishDate': 112},
#  {'date': '2020-03-17',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 361,
#   'cumCasesByPublishDate': 1557,
#   'newDeaths28DaysByPublishDate': 15,
#   'cumDeaths28DaysByPublishDate': 79},
#  {'date': '2020-03-16',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 97,
#   'cumCasesByPublishDate': 1196,
#   'newDeaths28DaysByPublishDate': 22,
#   'cumDeaths28DaysByPublishDate': 64},
#  {'date': '2020-03-15',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 253,
#   'cumCasesByPublishDate': 1099,
#   'newDeaths28DaysByPublishDate': 14,
#   'cumDeaths28DaysByPublishDate': 42},
#  {'date': '2020-03-14',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 201,
#   'cumCasesByPublishDate': 846,
#   'newDeaths28DaysByPublishDate': 18,
#   'cumDeaths28DaysByPublishDate': 28},
#  {'date': '2020-03-13',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 159,
#   'cumCasesByPublishDate': 645,
#   'newDeaths28DaysByPublishDate': 1,
#   'cumDeaths28DaysByPublishDate': 10},
#  {'date': '2020-03-12',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 99,
#   'cumCasesByPublishDate': 486,
#   'newDeaths28DaysByPublishDate': 2,
#   'cumDeaths28DaysByPublishDate': 9},
#  {'date': '2020-03-11',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 63,
#   'cumCasesByPublishDate': 387,
#   'newDeaths28DaysByPublishDate': 0,
#   'cumDeaths28DaysByPublishDate': 7},
#  {'date': '2020-03-10',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 46,
#   'cumCasesByPublishDate': 324,
#   'newDeaths28DaysByPublishDate': 4,
#   'cumDeaths28DaysByPublishDate': 7},
#  {'date': '2020-03-09',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 40,
#   'cumCasesByPublishDate': 282,
#   'newDeaths28DaysByPublishDate': 1,
#   'cumDeaths28DaysByPublishDate': 3},
#  {'date': '2020-03-08',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 58,
#   'cumCasesByPublishDate': 241,
#   'newDeaths28DaysByPublishDate': 0,
#   'cumDeaths28DaysByPublishDate': 2},
#  {'date': '2020-03-07',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 39,
#   'cumCasesByPublishDate': 183,
#   'newDeaths28DaysByPublishDate': 1,
#   'cumDeaths28DaysByPublishDate': 2},
#  {'date': '2020-03-06',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 39,
#   'cumCasesByPublishDate': 144,
#   'newDeaths28DaysByPublishDate': 1,
#   'cumDeaths28DaysByPublishDate': 1},
#  {'date': '2020-03-05',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 25,
#   'cumCasesByPublishDate': 105,
#   'newDeaths28DaysByPublishDate': None,
#   'cumDeaths28DaysByPublishDate': None},
#  {'date': '2020-03-04',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 32,
#   'cumCasesByPublishDate': 80,
#   'newDeaths28DaysByPublishDate': None,
#   'cumDeaths28DaysByPublishDate': None},
#  {'date': '2020-03-03',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 11,
#   'cumCasesByPublishDate': 48,
#   'newDeaths28DaysByPublishDate': None,
#   'cumDeaths28DaysByPublishDate': None},
#  {'date': '2020-03-02',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 4,
#   'cumCasesByPublishDate': 37,
#   'newDeaths28DaysByPublishDate': None,
#   'cumDeaths28DaysByPublishDate': None},
#  {'date': '2020-03-01',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 12,
#   'cumCasesByPublishDate': 33,
#   'newDeaths28DaysByPublishDate': None,
#   'cumDeaths28DaysByPublishDate': None},
#  {'date': '2020-02-29',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 3,
#   'cumCasesByPublishDate': 21,
#   'newDeaths28DaysByPublishDate': None,
#   'cumDeaths28DaysByPublishDate': None},
#  {'date': '2020-02-28',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 5,
#   'cumCasesByPublishDate': 18,
#   'newDeaths28DaysByPublishDate': None,
#   'cumDeaths28DaysByPublishDate': None},
#  {'date': '2020-02-27',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 0,
#   'cumCasesByPublishDate': 13,
#   'newDeaths28DaysByPublishDate': None,
#   'cumDeaths28DaysByPublishDate': None},
#  {'date': '2020-02-26',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 0,
#   'cumCasesByPublishDate': 13,
#   'newDeaths28DaysByPublishDate': None,
#   'cumDeaths28DaysByPublishDate': None},
#  {'date': '2020-02-25',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 0,
#   'cumCasesByPublishDate': 13,
#   'newDeaths28DaysByPublishDate': None,
#   'cumDeaths28DaysByPublishDate': None},
#  {'date': '2020-02-24',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 4,
#   'cumCasesByPublishDate': 13,
#   'newDeaths28DaysByPublishDate': None,
#   'cumDeaths28DaysByPublishDate': None},
#  {'date': '2020-02-23',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 0,
#   'cumCasesByPublishDate': 9,
#   'newDeaths28DaysByPublishDate': None,
#   'cumDeaths28DaysByPublishDate': None},
#  {'date': '2020-02-22',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 0,
#   'cumCasesByPublishDate': 9,
#   'newDeaths28DaysByPublishDate': None,
#   'cumDeaths28DaysByPublishDate': None},
#  {'date': '2020-02-21',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 0,
#   'cumCasesByPublishDate': 9,
#   'newDeaths28DaysByPublishDate': None,
#   'cumDeaths28DaysByPublishDate': None},
#  {'date': '2020-02-20',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 0,
#   'cumCasesByPublishDate': 9,
#   'newDeaths28DaysByPublishDate': None,
#   'cumDeaths28DaysByPublishDate': None},
#  {'date': '2020-02-19',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 0,
#   'cumCasesByPublishDate': 9,
#   'newDeaths28DaysByPublishDate': None,
#   'cumDeaths28DaysByPublishDate': None},
#  {'date': '2020-02-18',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 0,
#   'cumCasesByPublishDate': 9,
#   'newDeaths28DaysByPublishDate': None,
#   'cumDeaths28DaysByPublishDate': None},
#  {'date': '2020-02-17',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 0,
#   'cumCasesByPublishDate': 9,
#   'newDeaths28DaysByPublishDate': None,
#   'cumDeaths28DaysByPublishDate': None},
#  {'date': '2020-02-16',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 0,
#   'cumCasesByPublishDate': 9,
#   'newDeaths28DaysByPublishDate': None,
#   'cumDeaths28DaysByPublishDate': None},
#  {'date': '2020-02-15',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 0,
#   'cumCasesByPublishDate': 9,
#   'newDeaths28DaysByPublishDate': None,
#   'cumDeaths28DaysByPublishDate': None},
#  {'date': '2020-02-14',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 0,
#   'cumCasesByPublishDate': 9,
#   'newDeaths28DaysByPublishDate': None,
#   'cumDeaths28DaysByPublishDate': None},
#  {'date': '2020-02-13',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 1,
#   'cumCasesByPublishDate': 9,
#   'newDeaths28DaysByPublishDate': None,
#   'cumDeaths28DaysByPublishDate': None},
#  {'date': '2020-02-12',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 0,
#   'cumCasesByPublishDate': 8,
#   'newDeaths28DaysByPublishDate': None,
#   'cumDeaths28DaysByPublishDate': None},
#  {'date': '2020-02-11',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 0,
#   'cumCasesByPublishDate': 8,
#   'newDeaths28DaysByPublishDate': None,
#   'cumDeaths28DaysByPublishDate': None},
#  {'date': '2020-02-10',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 4,
#   'cumCasesByPublishDate': 8,
#   'newDeaths28DaysByPublishDate': None,
#   'cumDeaths28DaysByPublishDate': None},
#  {'date': '2020-02-09',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 1,
#   'cumCasesByPublishDate': 4,
#   'newDeaths28DaysByPublishDate': None,
#   'cumDeaths28DaysByPublishDate': None},
#  {'date': '2020-02-08',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 0,
#   'cumCasesByPublishDate': 3,
#   'newDeaths28DaysByPublishDate': None,
#   'cumDeaths28DaysByPublishDate': None},
#  {'date': '2020-02-07',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 0,
#   'cumCasesByPublishDate': 3,
#   'newDeaths28DaysByPublishDate': None,
#   'cumDeaths28DaysByPublishDate': None},
#  {'date': '2020-02-06',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 1,
#   'cumCasesByPublishDate': 3,
#   'newDeaths28DaysByPublishDate': None,
#   'cumDeaths28DaysByPublishDate': None},
#  {'date': '2020-02-05',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 0,
#   'cumCasesByPublishDate': 2,
#   'newDeaths28DaysByPublishDate': None,
#   'cumDeaths28DaysByPublishDate': None},
#  {'date': '2020-02-04',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 0,
#   'cumCasesByPublishDate': 2,
#   'newDeaths28DaysByPublishDate': None,
#   'cumDeaths28DaysByPublishDate': None},
#  {'date': '2020-02-03',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 0,
#   'cumCasesByPublishDate': 2,
#   'newDeaths28DaysByPublishDate': None,
#   'cumDeaths28DaysByPublishDate': None},
#  {'date': '2020-02-02',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 0,
#   'cumCasesByPublishDate': 2,
#   'newDeaths28DaysByPublishDate': None,
#   'cumDeaths28DaysByPublishDate': None},
#  {'date': '2020-02-01',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 0,
#   'cumCasesByPublishDate': 2,
#   'newDeaths28DaysByPublishDate': None,
#   'cumDeaths28DaysByPublishDate': None},
#  {'date': '2020-01-31',
#   'name': 'England',
#   'code': 'E92000001',
#   'newCasesByPublishDate': 2,
#   'cumCasesByPublishDate': 2,
#   'newDeaths28DaysByPublishDate': None,
#   'cumDeaths28DaysByPublishDate': None}]
